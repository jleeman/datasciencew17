# %%
import requests     # how python goes onto the internet!
import re           # regex
from bs4 import BeautifulSoup # a python HTML parser (version 3)

# %%
# let's turn to stock prices
# http://finance.google.com/finance?q=aapl

# %%
symbol = 'aapl'

# %%
# Let's grab the raw html from the page
r = requests.get('http://finance.google.com/finance?q='+symbol) # the url of the google finance page goes in here

# %%
#b = BeautifulSoup(r.text, "html5lib") # create a beautifulsoup object
b = BeautifulSoup(r.text, 'html.parser') # try this line instead if you have problems
print b
# Out:
# <!DOCTYPE html>
# <html><head><script>(function(){(function(){function e(a){this.t={};this.tick=function(a,c,b){var d=void 0!=b?b:(new Date).getTime();this.t[a]=[d,c];if(void 0==b)try{window.console.timeStamp("CSI/"+a)}catch(h){}};this.tick("start",null,a)}var a,d;window.performance&&(d=(a=window.performance.timing)&&a.responseStart);var f=0<d?new e(d):new e;window.jstiming={Timer:e,load:f};if(a){var c=a.navigationStart;0<c&&d>=c&&(window.jstiming.srt=d-c)}if(a){var b=window.jstiming.load;0<c&&d>=c&&(b.tick("_wtsrt",void 0,c),b.tick("wtsrt_","_wtsrt",
# d),b.tick("tbsd_","wtsrt_"))}try{a=null,window.chrome&&window.chrome.csi&&(a=Math.floor(window.chrome.csi().pageT),b&&0<c&&(b.tick("_tbnd",void 0,window.chrome.csi().startE),b.tick("tbnd_","_tbnd",c))),null==a&&window.gtbExternal&&(a=window.gtbExternal.pageT()),null==a&&window.external&&(a=window.external.pageT,b&&0<c&&(b.tick("_tbnd",void 0,window.external.startE),b.tick("tbnd_","_tbnd",c))),a&&(window.jstiming.pt=a)}catch(g){}})();}).call(this);
# </script><title>Apple Inc.: NASDAQ:AAPL quotes &amp; news - Google Finance</title><meta content="Get detailed financial information on Apple Inc. (NASDAQ:AAPL) including real-time stock quotes, historical charts &amp; financial news, all for free!" name="Description"><meta content="IE=10" http-equiv="X-UA-Compatible"><link href="http://www.google.com/finance?cid=22144" rel="canonical"><link href="/finance/f/finance_us-1489929081.css" rel="stylesheet" type="text/css"><link href="/_/scs/finance-static/_/ss/k=finance.a.x7heix82rby5.L.W.O/d=0/rs=AGHGApFPN2TpOk8r5vkQgPd47Zv7Pkrwuw" rel="stylesheet" type="text/css"><link href="/finance/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"><style>#gbar,#guser{font-size:13px;padding-right:8px;padding-top:4px !important;}#gbar{padding-left:8px;height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;position:absolute;top:24px;width:100%}@media all{.gb1{height:22px;margin-right:.5em;vertical-align:top}#gbar{float:left}}a.gb1,a.gb4{text-decoration:underline !important}a.gb1,a.gb4{color:#00c !important}.gbi .gb4{color:#dd8e27 !important}.gbf .gb4{color:#900 !important}
# </style><script></script><script async="" defer="" src="//www.google.com/insights/consumersurveys/async_survey?site=xusttduenzseze54mcajwbd6sq"></script><script>
#       function _rpt() {}
#       function _tck() {}
#     </script><script>
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#     ga('create', 'UA-40765809-1', {
#       'allowLinker': true,
#       'cookiePath': '/finance'
#     });
#     ga('send', 'pageview');
#     </script></link></link></link></link></meta></meta></head><body><div class="fjfe-bodywrapper"><div class="g-doc" id="fjfe-real-body"><input id="hist_state" name="hist_state" style="display:none;" type="text"><iframe class="invfr" id="hist_frame" name="hist_frame" tabindex="-1"></iframe><iframe class="invfr" src="/_/scs/finance-static/_/js/k=finance.a.en_US.9R147Dhnn8c.O/m=b/rt=h/d=0/rs=AGHGApGszSEHbMoXAq0_ObWO6zwfX-urUw" tabindex="-1"></iframe><div id="gbar"><nobr><a class="gb1" href="https://www.google.com/webhp?tab=ew">Search</a> <a class="gb1" href="http://www.google.com/imghp?hl=en&amp;tab=ei">Images</a> <a class="gb1" href="http://maps.google.com/maps?hl=en&amp;tab=el">Maps</a> <a class="gb1" href="https://play.google.com/?hl=en&amp;tab=e8">Play</a> <a class="gb1" href="http://www.youtube.com/?tab=e1">YouTube</a> <a class="gb1" href="http://news.google.com/nwshp?hl=en&amp;tab=en">News</a> <a class="gb1" href="https://mail.google.com/mail/?tab=em">Gmail</a> <a class="gb1" href="https://drive.google.com/?tab=eo">Drive</a> <a class="gb1" href="https://www.google.com/intl/en/options/" style="text-decoration:none"><u>More</u> »</a></nobr></div><div id="guser" width="100%"><nobr><span class="gbi" id="gbn"></span><span class="gbf" id="gbf"></span><span id="gbe"></span><a class="gb4" href="http://www.google.com/support/finance?hl=en">Help</a> | <a class="gb4" href="https://accounts.google.com/ServiceLogin?service=finance&amp;passive=1209600&amp;continue=http://www.google.com/finance?q%3Daapl&amp;followup=http://www.google.com/finance?q%3Daapl" id="gb_70" target="_top">Sign in</a></nobr></div><div class="gbh" style="left:0"></div><div class="gbh" style="right:0"></div><div id="fjfe-click-wrapper"><script>
# (function() {
#   var l = window.location;
#   var q = l.search ? l.search.substr(1) : '';
#   var h = l.hash ? l.hash.substr(1) : '';
#   var p = '/finance';
#   var ss = 'stockscreener';
#   var conn = window.history && window.history.pushState ? '/' : '#';
#   if (l.pathname == p + '/' + ss) {
#     if (h) l.href = p + conn + ss + '?' + q + '&' + h;
#   } else if (l.pathname != p && h) {
#     l.href = p + l.hash;
#   }
#   if (h) {
# document.getElementById('fjfe-click-wrapper').style.display = 'none';
#   }
# })();
# </script><div class="g-section g-tpl-75-25 g-split" id="gf-head"><div class="g-unit g-first"><div class="fjfe-logo"><a href="/finance/?ei=25jZWNCaJoSje5bbhcgJ"><img alt="Google Finance" src="/finance/f/logo_material-4224265490.png"/></a></div><div class="fjfe-search" id="gf-search"><form action="/finance" autocomplete="off" method="get"><input class="fjfe-searchbox-input" name="q" tabindex="1" type="text" value="NASDAQ:AAPL"/><span class="fjfe-searchbox-button-wrapper"><span class="fjfe-searchbox-button-wrapper2"><input class="fjfe-searchbox-button" tabindex="2" type="submit" value="Get quotes"/></span></span><input name="ei" type="hidden" value="25jZWNCaJoSje5bbhcgJ"/></form></div></div><div class="g-unit fjfe-promo"><div class="id-ad2-target" id="ad2-target"></div></div></div><div class="elastic"><div class="g-section g-tpl-left-11p4em" id="app"><div class="g-unit g-first"><div id="gf-nav"><div class="fjfe-nav-nav"><ul class="fjfe-nav" id="navmenu"><li class="fjfe-nav-expanded fjfe-nav-selected">Company<li class="fjfe-nav-sub"><div>Summary</div><li class="fjfe-nav-sub"><a href="/finance/company_news?q=NASDAQ:AAPL&amp;ei=25jZWNCaJoSje5bbhcgJ">News</a><li class="fjfe-nav-sub"><a href="/finance/option_chain?q=NASDAQ:AAPL&amp;ei=25jZWNCaJoSje5bbhcgJ">Option chain</a><li class="fjfe-nav-sub"><a href="/finance/related?q=NASDAQ:AAPL&amp;ei=25jZWNCaJoSje5bbhcgJ">Related companies</a><li class="fjfe-nav-sub"><a href="/finance/historical?q=NASDAQ:AAPL&amp;ei=25jZWNCaJoSje5bbhcgJ">Historical prices</a><li class="fjfe-nav-sub"><a href="/finance?q=NASDAQ:AAPL&amp;fstype=ii&amp;ei=25jZWNCaJoSje5bbhcgJ">Financials</a><li class="fjfe-nav-item"><a href="/finance?ei=25jZWNCaJoSje5bbhcgJ"><div>Markets</div></a><li class="fjfe-nav-item"><a href="/finance/market_news?ei=25jZWNCaJoSje5bbhcgJ"><div>News</div></a><li class="fjfe-nav-item"><a href="/finance/portfolio?action=view&amp;ei=25jZWNCaJoSje5bbhcgJ"><div>Portfolios</div></a><li class="fjfe-nav-item"><a href="/finance/stockscreener?ei=25jZWNCaJoSje5bbhcgJ"><div>Stock screener</div></a><li class="fjfe-nav-item"><a href="/finance/domestic_trends?ei=25jZWNCaJoSje5bbhcgJ"><div>Google Domestic Trends</div></a></li></li></li></li></li></li></li></li></li></li></li></li></ul></div><div class="fjfe-recentquotes fjfe-recentquotes-noquote"><h4>Recent Quotes <span class="fjfe-recentquotes-duration">(<a href="//www.google.com/history/optout?hl=en">30 days</a>)</span></h4><div class="fjfe-recentquotes-noquote-notification">You have no recent quotes</div><div class="fjfe-recentquotes-quotes"><div class="fjfe-toggle fjfe-toggle-button"><span class="fjfe-chg-toggle">chg</span> | <span class="fjfe-perc-toggle">%</span></div><div class="fjfe-table-div"><table class="fjfe-recentquotes-table" id="rq" width="100%"></table></div></div></div></div><script>var _cleardot = '...\/\/\/\/\/\/\/yH5BAEKAAEALAAAAAABAAEAAAICTAEAOw\x3d\x3d';
#     var google = google || {};
#     google.finance = google.finance || {};
#     google.finance.gce = false ;</script><script src="/finance/f/sfe-opt-1767485581.js"></script><script>
#       _regOnLoad = function(f) {
#         if (document.readyState == 'complete') {
#           f && f();
#         } else {
#           // Window.attachEvent() for IE8 and below compatability.
#           var addEventFunction = window.attachEvent ||
#               window.addEventListener || function(ignored, f) { f(); };
#           var event = window.attachEvent ? 'onload' : 'load';
#           f && addEventFunction(event, f);
#         }
#       };
#
#       google.finance.renderRecentQuotes = function() {};
#     </script></div><div class="g-unit" id="gf-viewc"><div class="fjfe-content">
# <script>
# (function() {
# if (window['_finance_chart']) {
# var el = document.getElementById('chart_anchor');
# if (el) {
# el.innerHTML = '';
# }
# setFinanceChart(null);
# }
# })();
# var _ticker = 'NASDAQ:AAPL';
# var _slHeight = 221;
# var _companyName = 'Apple Inc.';
# var _companyPageNewsTab = '0';
# var _displayVolume = true;
# setCompanyId(22144);
# _s_Store._numToDisplay = 6;
# _comparison_charts_Store._numToDisplay = 8;
# _comparison_charts_Store._allowMultiTimezoneCompare = true;
# function onCompanyLoad() {
# _external_target = "";
# _emitFlashChartOnLoad(
# "/finance/s/n-VxNKK74DU/chart9.swf?hl=en&gl=us",
# _ticker, "chart_anchor", "market-data-div",
# _chartConfigObject);
# google.finance.onCompanyLoad();
# _initAutoFocus();
# if (google.finance.initTechnicals) {
# google.finance.initTechnicals(true);
# }
# }
# </script>
# <div class="g-wrap">
# <div class="g-section sfe-break-bottom-8">
# <div class="g-tpl-67-33 g-split hdg top appbar-hide" id="companyheader">
# <div class="g-unit g-first"><h3>Apple Inc.  </h3>(Public, NASDAQ:AAPL)
# <a class="norm" href="/finance/portfolio?action=add&amp;addticker=NASDAQ%3AAAPL&amp;ei=25jZWNCaJoSje5bbhcgJ">Watch this stock</a>
#
# </div><div class="g-unit norm">Find more results for<b>
# <a href="?noIL=1&amp;q=aapl&amp;ei=25jZWNCaJoSje5bbhcgJ" id="searchmore">aapl</a></b>
# </div>
# </div>
# </div>
# <script>
# _ac_register(function (input, event) {
# if (input.id == 'add_comparison_symbol') {
# _comparison_charts_Store.baseTicker = "NASDAQ:AAPL";
# return _comparison_charts_Store;
# }
# });
# var _prefs=_prefs||{};_prefs.hash="";
# _prefs.feeds=_prefs.feeds||{};
# _prefs.ch=_prefs.ch||{};
# _prefs.ch_compare=_prefs.ch_compare||{};
# var _chartConfigObject;
# var _cleardot;
# var _companyName;
# var _eventid = '25jZWNCaJoSje5bbhcgJ';
# var _expid;
# var _external_target;
# var _localDomain = 'www.google.com';
# var _minZoomDays;
# var _minZoomDaysNoIntraDay;
# var _prefs;
# var _ticker;
# var _urlSuffix;
# var google = google || {};
# google.finance = google.finance || {};
# google.finance.data = {common:{rq:{ct:""},up:"chg",down:"chr",linktargetInternal:"",hash:"",dfp:"ad-g.doubleclick.net/adi/com.gf.company/technology;fe=nasdaq;ft=aapl;fm=large;dcopt=ist;myd=ad;sz=300x250;tile=1",streaming:[{cid:"22144",s:"AAPL",e:"NASDAQ"},{cid:"180086490123759",s:"SSNNF",e:"OTCMKTS"},{cid:"358464",s:"MSFT",e:"NASDAQ"},{cid:"664887",s:"VZ",e:"NYSE"},{cid:"17154",s:"HPQ",e:"NYSE"},{cid:"694653",s:"GOOGL",e:"NASDAQ"},{cid:"33095",s:"SNE",e:"NYSE"},{cid:"7583206",s:"HTCKF",e:"OTCMKTS"},{cid:"662925",s:"NVDA",e:"NASDAQ"},{cid:"661895",s:"DTEGY",e:"OTCMKTS"},{cid:"4112",s:"ADBE",e:"NASDAQ"}],dfp_companion:"ad-g.doubleclick.net/adi/com.gf.company/technology;fe=nasdaq;ft=aapl;fm=large;dcopt=ist;myd=ad2;sz=33x33;tile=2"},company:{news:{clusters:[{nrel:26,idx:0,id:"52779439655144",lead_story_url:"https://www.fool.com/investing/2017/03/27/report-apple-inc-supplier-to-start-building-a11-ch.aspx?source=iedfolrf0000001",a:[{t:"Report: Apple Inc. Supplier to Start Building A11 Chip in April",u:"https://www.fool.com/investing/2017/03/27/report-apple-inc-supplier-to-start-building-a11-ch.aspx?source=iedfolrf0000001",s:"Motley Fool",sp:"Remember that, today, Apple is selling the iPhone 7 series, iPhone 6s series, and iPhone SE smartphones. The iPhone 7 is powered by the A10 Fusion, built exclusively by TSMC, while the iPhone 6s and SE devices are powered by Apple\u0026#39;s A9 chip -- a chip\u0026nbsp;...",d:"3 hours ago",tt:"1490643000",usg:"AFQjCNHHMESM0FWOHNIv0YaJDXUwaTvCHQ",sru:"http://news.google.com/news/url?sa=T\u0026ct2=us\u0026fd=S\u0026url=https://www.fool.com/investing/2017/03/27/report-apple-inc-supplier-to-start-building-a11-ch.aspx%3Fsource%3Diedfolrf0000001\u0026cid=52779439655144\u0026ei=O5jZWIHEE9iGe_atlegC\u0026usg=AFQjCNE3DPsLNEqqen1hBrhw3CbK31gg_g"},{t:"TSMC to supply 100 mil. new chips for Apple",u:"http://www.chinapost.com.tw/business/company-focus/2017/03/28/494414/TSMC-to.htm",s:"China Post",sp:"Citing sources from TSMC\u0026#39;s supply chain, the Chinese-language Economic Daily News said Apple had demanded the firm produce at least 50 million chips by July, adding that the chipmaker\u0026#39;s record-breaking production goals could reflect Apple\u0026#39;s confidence\u0026nbsp;...",d:"7 hours ago",tt:"1490630175",usg:"AFQjCNFJvnW84hJykYgbSILJFeOB4sjMqQ",sru:"http://news.google.com/news/url?sa=T\u0026ct2=us\u0026fd=S\u0026url=http://www.chinapost.com.tw/business/company-focus/2017/03/28/494414/TSMC-to.htm\u0026cid=52779439655144\u0026ei=O5jZWIHEE9iGe_atlegC\u0026usg=AFQjCNHCdT7VnRxoDD3T75kRj7lR_FR_2A"}],lead_story_doc_id:"540139502031480647"},{nrel:11,idx:1,id:"52779439947972",lead_story_url:"http://www.valuewalk.com/2017/03/apple-releases-2016-supplier-responsibility-report/",a:[{t:"Apple Releases 2016 Supplier Responsibility Report",u:"http://www.valuewalk.com/2017/03/apple-releases-2016-supplier-responsibility-report/",s:"ValueWalk",sp:"Apple Inc. (NASDAQ:AAPL) has just released its eleventh annual Supplier Responsibility Report, and the company reported progress in several areas, including UL Zero Waste to Landfill validation, use of conflict minerals, and others.",d:"7 hours ago",tt:"1490627475",usg:"AFQjCNEVjUK8z1si7fWcxFyKFA6dVe9tbQ",sru:"http://news.google.com/news/url?sa=T\u0026ct2=us\u0026fd=S\u0026url=http://www.valuewalk.com/2017/03/apple-releases-2016-supplier-responsibility-report/\u0026cid=52779439947972\u0026ei=O5jZWIHEE9iGe_atlegC\u0026usg=AFQjCNG2IDsro5J3tj-EqJFEYY8NIErbvQ"},{t:"Raising the bar: Apple\u0026#39;s 11th annual Supplier Responsibility progress report ...",u:"http://www.apple.com/newsroom/2017/03/raising-the-bar-apples-11th-annual-supplier-responsibility-progress-report-released.html",s:"Apple Newsroom (press release)",sp:"Apple believes everyone in its supply chain deserves dignity and respect. From stricter standards to improving working conditions and protecting the planet, Apple raises the bar higher for its suppliers and the industry. See highlights in the new ...",d:" ...
# google.finance.data.numberFormat = [{'threshold':1000000, 'symbol':'M'}, {'threshold':1000000000,'symbol':'B'}, {'threshold':1000000000000,'symbol':'T'}] ;
# _setStickyUrlParams("ei=25jZWNCaJoSje5bbhcgJ");
# if (_s_Store) {
# _s_Store._allowMatchAdvancedSearch = true;
# var _fieldToDisplayNameMap = {GrossMargin:"Gross margin&nbsp;(%)",Return1Week:"1w return",Return156Week:"156w return",NextYearEPS:"Next year EPS",LTDebtToAssetsYear:"LT debt/assets (Recent&nbsp;yr)&nbsp;(%)",RevenueGrowthRate5Years:"5y revenue growth rate",EarningsAfterTaxes:"Earnings after taxes",DividendPerShare:"Div per share",MarketCap:"Market cap",NetProfitMarginPercent:"Net profit margin&nbsp;(%)",Float:"Float",EarningsBeforeTaxes:"Earnings before taxes",QuotePercChange:"Quote change&nbsp;(%)",TotalDebtToEquityYear:"Total debt/equity (Recent&nbsp;yr)&nbsp;(%)",TotalDebtToCapitalQuarter:"Total debt/capital (Recent&nbsp;qtr)&nbsp;(%)",LTDebtToCapitalQuarter:"LT debt/capital (Recent&nbsp;qtr)&nbsp;(%)",EPSGrowthRate10Years:"10y EPS growth rate",Beta:"Beta",ReturnOnAssetsPTM:"Return on assets (PTM)&nbsp;(%)",CapitalGain:"Capital gain",BetaDown:"Beta down from RAS",IncomeDividend:"Income dividend",RevenueGrowthRate10Years:"10y revenue growth rate",MarketCapShareBasis:"Market cap share basis",IAD:"Div rate indicated annual",Return4Week:"4w return",Price150DayAverage:"150d avg price",EPSGrowthRate5Years:"5y EPS growth rate",ReturnOnAssetsTTM:"Return on assets (TTM)&nbsp;(%)",TotalDebtToAssetsYear:"Total debt/assets (Recent&nbsp;yr)&nbsp;(%)",Volume:"Volume",DividendRecentQuarter:"Div recent quarter",CurrentRatioYear:"Current ratio",Low52Week:"52w low",ExpenseRatio:"Expense ratio",Price13WeekPercChange:"13w&nbsp;price change&nbsp;(%)",Price1DayPercChange:"1d&nbsp;price change&nbsp;(%)",ReturnOnEquity5Years:"Return on equity (5&nbsp;yr&nbsp;avg)&nbsp;(%)",TotalDebtToCapitalYear:"Total debt/capital (Recent&nbsp;yr)&nbsp;(%)",TotalDebtToAssetsQuarter:"Total debt/assets (Recent&nbsp;qtr)&nbsp;(%)",NavChange:"Nav change",OperatingMargin:"Operating margin&nbsp;(%)",DPSRecentYear:"Div per share (Recent&nbsp;yr)",ANI:"Earnings after taxes (Recent&nbsp;yr)",AverageVolume:"Average volume",High52Week:"52w high",Return13Week:"13w return",PriceToCashFlowPerShare:"Price to cash flow per share",ATAXRATE:"Tax rate (Recent&nbsp;yr)",Price26WeekPercChange:"26w&nbsp;price change&nbsp;(%)",QuoteChange:"Quote change",NetIncomeChangePerc:"Net income change&nbsp;(%)",ReturnOnInvestment5Years:"Return on investment (5&nbsp;yr&nbsp;avg)&nbsp;(%)",PE:"P/E ratio",ReturnOnInvestmentYear:"Return on investment (Recent&nbsp;yr)&nbsp;(%)",Price200DayAverage:"200d avg price",DividendNextQuarter:"Div next quarter",EBITD:"EBITDA",PriceYTDPercChange:"YTD&nbsp;price change&nbsp;(%)",ReturnOnInvestmentTTM:"Return on investment (TTM)&nbsp;(%)",NavChangePercent:"Nav change&nbsp;(%)",EBITDMargin:"EBITDA margin&nbsp;(%)",LTDebtToEquityQuarter:"LT debt/equity (Recent&nbsp;qtr)&nbsp;(%)",BetaRAS:"Beta from RAS",PriceSales:"Price to sales",NetAssets:"Net assets",ReturnOnEquityTTM:"Return on equity (TTM)&nbsp;(%)",CashPerShareYear:"Cash/share",ReturnOnAssets5Years:"Return on assets (5&nbsp;yr&nbsp;avg)&nbsp;(%)",ReturnDay:"1d return",Return52Week:"52w return",ForwardPE1Year:"1y fwd P/E",NetIncomeGrowthRate5Years:"5y net income growth rate",DividendYield:"Div yield&nbsp;(%)",Dividend:"Div from cash flow",BetaUp:"Beta up from RAS",LTDebtToCapitalYear:"LT debt/capital (Recent&nbsp;yr)&nbsp;(%)",nprice:"Price from RAS",Return260Week:"260w return",ReturnOnEquityQuarter:"Return on equity (Recent&nbsp;qtr)&nbsp;(%)",ACOGS:"Cost of goods sold",LTDebtToAssetsQuarter:"LT debt/assets (Recent&nbsp;qtr)&nbsp;(%)",PriceToBook:"Price to book",LTDebtToEquityYear:"LT debt/equity (Recent&nbsp;yr)&nbsp;(%)",ReturnYTD:"Return YTD",ReturnOnEquityYear:"Return on equity (Recent&nbsp;yr)&nbsp;(%)",ReturnOnAssetsQuarter:"Return on assets (Recent&nbsp;qtr)&nbsp;(%)",TotalDebtToEquityQuarter:"Total debt/equity (Recent&nbsp;qtr)&nbsp;(%)",NavPrior:"Nav prior",AINTCOV:"Interest coverage",EPS:"EPS",ReturnOnInvestmentQuarter:"Return on investment (Recent&nbsp;qtr)&nbsp;(%)",QuoteLast:"Last price",Price50DayAverage:"50d avg price",Price4WeekPercChange:"4w&nbsp;price change&nbsp;(%)",ReturnOnAssetsYear:"Ret ...
# _s_Store._asStore._addStrings(_fieldToDisplayNameMap);
# }
# if (_s_Store) {
# _s_Store._allowMultipleInBox = true;
# }
# google.finance.renderRecentQuotes();
# </script>
# <div class="g-section g-tpl-right-1">
# <div class="g-unit g-first">
# <div class="g-c">
# <div class="g-section g-tpl-67-33 g-split nwp" id="r-perf">
# <div class="id-r-perf-quotes g-unit g-first" id="r-perf-quotes"></div>
# <div class="id-r-perf-charts g-unit" id="r-perf-charts"></div>
# </div>
# <script>google.finance.renderRelativePerformance();</script>
# </div>
# </div>
# <div class="g-unit">
# <div class="id-market-data-div nwp g-floatfix" id="market-data-div">
# <div class="id-price-panel goog-inline-block" id="price-panel">
# <div>
# <span class="pr">
# <span id="ref_22144_l">140.88</span>
# </span>
# <div class="id-price-change nwp">
# <span class="ch bld"><span class="chg" id="ref_22144_c">+0.24</span>
# <span class="chg" id="ref_22144_cp">(0.17%)</span>
# </span>
# </div>
# </div>
# <div>After Hours: <span class="bld" id="ref_22144_el">140.95</span>
# <span class="chg" id="ref_22144_ec">+0.07</span>
# <span class="chg" id="ref_22144_ecp">(0.05%)</span>
# <div id="ref_22144_elt">Mar 27, 6:44PM EDT  <div class="mdata-dis">
# <span class="dis-large"><nobr>NASDAQ
# real-time data -
# <a class="dis-large" href="//www.google.com/help/stock_disclaimer.html#realtime">Disclaimer</a>
# </nobr></span>
# <div>Currency in USD</div>
# </div>
# </div>
# </div>
# </div>
# <div class="snap-panel-and-plusone">
# <div class="snap-panel">
# <table class="snap-data">
# <tr>
# <td class="key" data-snapfield="range">Range
# </td>
# <td class="val">138.62 - 141.22
# </td>
# </tr>
# <tr>
# <td class="key" data-snapfield="range_52week">52 week
# </td>
# <td class="val">89.47 - 142.80
# </td>
# </tr>
# <tr>
# <td class="key" data-snapfield="open">Open
# </td>
# <td class="val">139.39
# </td>
# </tr>
# <tr>
# <td class="key" data-snapfield="vol_and_avg">Vol / Avg.
# </td>
# <td class="val">23.57M/24.12M
# </td>
# </tr>
# <tr>
# <td class="key" data-snapfield="market_cap">Mkt cap
# </td>
# <td class="val">737.66B
# </td>
# </tr>
# <tr>
# <td class="key" data-snapfield="pe_ratio">P/E
# </td>
# <td class="val">16.87
# </td>
# </tr></table><table class="snap-data">
# <tr>
# <td class="key" data-snapfield="latest_dividend-dividend_yield">Div/yield
# </td>
# <td class="val">0.57/1.62
# </td>
# </tr>
# <tr>
# <td class="key" data-snapfield="eps">EPS
# </td>
# <td class="val">8.35
# </td>
# </tr>
# <tr>
# <td class="key" data-snapfield="shares">Shares
# </td>
# <td class="val">5.25B
# </td>
# </tr>
# <tr>
# <td class="key" data-snapfield="beta">Beta
# </td>
# <td class="val">1.25
# </td>
# </tr>
# <tr>
# <td class="key" data-snapfield="inst_own">Inst. own
# </td>
# <td class="val">61%
# </td>
# </tr>
# </table>
# </div>
# <div class="plusone-box" id="plusone-box">
# <g:plusone size="standard" source="google:FINANCE"></g:plusone></div>
# </div>
# </div>
# <script>google.finance.renderMarketData();</script>
# <div id="sharebox-data" itemscope="itemscope" itemtype="http://schema.org/Intangible/FinancialQuote">
# <meta content="Apple Inc." itemprop="name"/>
# <meta content="https://www.google.com/finance?cid=22144" itemprop="url"/>
# <meta content="https://www.google.com/finance/chart?cht=g&amp;q=NASDAQ:AAPL&amp;tkr=1&amp;p=1d&amp;enddatetime=2017-03-27T16:00:08Z" itemprop="imageUrl"/>
# <meta content="AAPL" itemprop="tickerSymbol"/>
# <meta content="NASDAQ" itemprop="exchange"/>
# <meta content="America/New_York" itemprop="exchangeTimezone"/>
# <meta content="140.88" itemprop="price"/>
# <meta content="+0.24" itemprop="priceChange"/>
# <meta content="0.17" itemprop="priceChangePercent"/>
# <meta content="true" itemprop="isAfterHours">
# <meta content="140.95" itemprop="afterHoursPrice">
# <meta content="+0.07" itemprop="afterHoursPriceChange">
# <meta content="0.05" itemprop="afterHoursPriceChangePercent">
# <meta content="2017-03-27T22:44:57Z" itemprop="afterHoursQuoteTime">
# <meta content="2017-03-27T16:00:08Z" itemprop="quoteTime"/>
# <meta content="NASDAQ real-time data" itemprop="dataSource"/>
# <meta content="//www.google.com/help/stock_disclaimer.html#realtime" itemprop="dataSourceDisclaimerUrl"/>
# <meta content="USD" itemprop="priceCurrency"/>
# </meta></meta></meta></meta></meta></div>
# </div>
# </div>
# <div class="g-section g-tpl-right-1 sfe-break-top-5">
# <div class="g-unit g-first">
# <div class="g-c"><div>
# <div id="newstabsgroup">
# <div class="g-section g-tpl-25-75 g-split hdg">
# <div class="g-unit g-first">
# <h3>News</h3>
# </div>
# <div class="g-unit">
# <div class="id-news-tabs" id="news-panel-tabs" style="display:none;">
# <div class="goog-tab goog-tab-selected">
# <a class="t" id="news_tab_title">
# <b class="t"><b class="t">Relevance</b></b></a>
# </div>
# <div class="goog-tab">
# <a class="t" id="news_by_date_tab_title">
# <b class="t"><b class="t">Date</b></b></a>
# </div>
# </div>
# </div>
# </div>
# <div class="id-tabs-clear goog-tab-bar-clear hide" id="tabs-clear"></div>
# <div class="id-news_div_cont" id="news_div_cont" style="display:none;"></div>
# <div class="id-news_by_date_div_cont" id="news_by_date_div_cont" style="display:none;"></div>
# </div>
# <div class="sfe-section clf" id="news-footer">
# <div class="g-section g-tpl-67-33 g-split" id="news-sidebar-footer">
# <div class="g-unit g-first">
# <a href="/finance/company_news?q=NASDAQ:AAPL&amp;ei=25jZWNCaJoSje5bbhcgJ">All news for Apple Inc. »</a>
# </div><div class="g-unit">
# <a href="/finance/company_news?q=NASDAQ:AAPL&amp;ei=25jZWNCaJoSje5bbhcgJ&amp;output=rss">Subscribe</a>
# <a href="/finance/company_news?q=NASDAQ:AAPL&amp;ei=25jZWNCaJoSje5bbhcgJ&amp;output=rss"><img alt="Subscribe." class="SP_subscribe" height="15" id="rss" src="/finance/s/m4C5KaofCbA/images/cleardot.gif" width="15"/></a>
# </div>
# </div>
# </div>
# </div>
# <div class="sfe-break-top sfe-break-bottom-16" id="ad">
# <div class="id-ad-label invisible" id="ad-label">Advertisement</div>
# <div class="id-ad-target ads-300-250" id="ad-target"></div>
# </div>
# <div class="g-section g-tpl-25-75 g-split hdg">
# <div class="g-unit g-first">
# <h3>Events</h3>
# </div>
# <div class="g-unit">
# <div class="sfe-break-right-em">
# <img alt="" class="SP_calendar" height="16" id="calendar" src="/finance/s/m4C5KaofCbA/images/cleardot.gif" width="16">
# <a href="//www.google.com/calendar/render?ei=25jZWNCaJoSje5bbhcgJ&amp;hl=en&amp;cid=http://www.google.com:80%2Ffinance%2Fevents%3Fq%3DNASDAQ%3AAAPL%26output%3Dical" onclick="_GF_click('', 'add_ical', 'AAPL', '')">Add AAPL to my calendars</a>
# </img></div>
# </div>
# </div>
# <div class="events sfe-section">
# <div class="event">
# <div class="bld date">Feb 24, 2017</div>
# <div>Apple Inc Annual Shareholders Meeting (Estimated)
# </div>
# </div>
# <div class="event">
# <div class="bld date">Jan 24, 2017</div>
# <div>Q1 2017 Apple Inc Earnings Release (Estimated)
# </div>
# </div>
# <table><tr>
# <td>
# <a href="//www.google.com/url?source=finance&amp;q=http%3A%2F%2Fwww.dailyfinance.com%2Fevent%2FAAPL%2Fusa&amp;ei=25jZWNCaJoSje5bbhcgJ&amp;usg=AFQjCNExUPW4pbcUCZOUbhnfAi7lW5hzVA">
# More events from DailyFinance »</a>
#   <nobr>
# </nobr></td>
# </tr></table>
# </div>
# <div class="hdg"><h3>Key stats and ratios</h3></div>
# <div class="sfe-section">
# <table class="quotes rgt nwp" width="100%">
# <thead><tr>
# <td width="50%">
# <td class="colHeader">Q4 (Dec '16)
# <td class="colHeader">2016
# </td></td></td></tr></thead>
# <tr>
# <td class="lft name">Net profit margin
# <td class="period">22.83%
# <td class="period">21.19%
# <tr>
# <td class="lft name">Operating margin
# <td class="period">29.81%
# <td class="period">27.84%
# <tr>
# <td class="lft name">EBITD margin
# <td class="period">-
# <td class="period">32.38%
# <tr>
# <td class="lft name">Return on average assets
# <td class="period">20.41%
# <td class="period">14.93%
# <tr>
# <td class="lft name">Return on average equity
# <td class="period">51.13%
# <td class="period">36.90%
# <tr>
# <td class="lft name">Employees
# <td class="period">116,000
# <td class="period">-
# <tr>
# <td class="lft name">CDP Score
# <td class="period">-
# <td class="period">
# <a href="//www.google.com/url?source=finance&amp;q=https%3A%2F%2Fwww.cdp.net%2Fen-US%2FResults%2FPages%2FCompany-Responses.aspx%3Fcompany%3D865&amp;ei=25jZWNCaJoSje5bbhcgJ&amp;usg=AFQjCNHAICF-3dHfVpNICAhcoz8ngfa5Jg" id="m-cdi">100 A</a>
# </td></td></td></tr></td></td></td></tr></td></td></td></tr></td></td></td></tr></td></td></td></tr></td></td></td></tr></td></td></td></tr></table>
# <div class="sfe-break-top">
# <a href="/finance/similar?q=NASDAQ:AAPL&amp;ei=25jZWNCaJoSje5bbhcgJ" id="similar">Screen stocks with similar metrics »</a></div>
# </div>
# <div class="hdg"><h3>Address</h3></div>
# <div class="sfe-section">1 Infinite Loop<br/>CUPERTINO, CA 95014-2083<br/>United States
# - <a href="http://maps.google.com/maps?ei=25jZWNCaJoSje5bbhcgJ&amp;q=1+Infinite+Loop+CUPERTINO+95014-2083+United+States%20(Apple+Inc.)">Map</a><br/>+1-408-9961010 (Phone)<br>
# </br></div>
# <div class="hdg"><h3>Website links</h3></div>
# <div class="sfe-section"><div class="item">
# <a href="//www.google.com/url?source=finance&amp;q=http%3A%2F%2Fwww.apple.com&amp;ei=25jZWNCaJoSje5bbhcgJ&amp;usg=AFQjCNHEvr1ucVBJbi5xOp24LQgfsg88-g" id="fs-chome">
# http://www.apple.com
# </a>
# </div>
# </div>
# <div class="hdg"><h3>External links</h3></div>
# <div class="sfe-section">
# <div class="item"><a href="//www.google.com/url?source=finance&amp;q=http%3A%2F%2Fwww.marketwatch.com%2Finvesting%2Fstock%2FAAPL%2Fanalystestimates&amp;ei=25jZWNCaJoSje5bbhcgJ&amp;usg=AFQjCNGKj3Cdn14v36A-FAsFsA5-4LNEzg" id="m-analyst">Analyst Estimates</a> - <font color="#6F6F6F">MarketWatch</font></div>
# <div class="item"><a href="//www.google.com/url?source=finance&amp;q=http%3A%2F%2Fgoogle.brand.edgar-online.com%3Fsym%3DAAPL&amp;ei=25jZWNCaJoSje5bbhcgJ&amp;usg=AFQjCNFqMZeu8kLF9lUDtLxmJK76O1n5bA" id="m-sec">SEC Filings</a> - <font color="#6F6F6F">EDGAR Online</font></div>
# <div class="item"><a href="//www.google.com/url?source=finance&amp;q=http%3A%2F%2Finvesting.money.msn.com%2Finvestments%2Finstitutional-ownership%3Fsymbol%3DAAPL&amp;ei=25jZWNCaJoSje5bbhcgJ&amp;usg=AFQjCNEf2SZ63K2UssEiOW0OBwdAzQr-Pg" id="m-hold">Major Holders</a> - <font color="#6F6F6F">MSN Money</font></div>
# <div class="item"><a href="//www.google.com/url?source=finance&amp;q=https%3A%2F%2Fcommerce.us.reuters.com%2Fpurchase%2FadvancedSearch.do%3Fsymbol%3DAAPL.O%26rpc%3D68&amp;ei=25jZWNCaJoSje5bbhcgJ&amp;usg=AFQjCNHYmOxRmSszcLFOfoTgUZeIYpokFA" id="m-research">Research Reports</a> - <font color="#6F6F6F">Reuters</font></div>
# <div class="item"><a href="//www.google.com/url?source=finance&amp;q=http%3A%2F%2Fwww.seekingalpha.com%2Ftranscripts%2Ffor%2FAAPL&amp;ei=25jZWNCaJoSje5bbhcgJ&amp;usg=AFQjCNG8_VPQtpK9E0pjlQqUwtJCAS-fcQ" id="m-transcripts">Transcripts</a> - <font color="#6F6F6F">SeekingAlpha</font></div>
# <div class="item"><a href="//www.google.com/url?source=finance&amp;q=http%3A%2F%2Fen.wikipedia.org%2Fwiki%2FApple_Computer&amp;ei=25jZWNCaJoSje5bbhcgJ&amp;usg=AFQjCNHFN8-fAWbQqppXuyR1bKrbWoo-iQ" id="m-wiki">About Company</a> - <font color="#6F6F6F">Wikipedia</font></div>
# </div>
# </div>
# </div>
# <div class="g-unit">
# <div class="g-c sfe-break-right" id="top-section">
# <div id="chart-section">
# <div>
# <div class="id-compare-bar-wrapper" id="compare-bar-wrapper">
# <div class="id-compare-bar g-section" id="compare-bar">
# </div>
# </div>
# <div class="id-chart_anchor" id="chart_anchor"></div>
# <div class="id-chart-footer">
# <div class="g-section g-tpl-67-33 g-split sfe-break-bottom-8 overflow-floatfix">
# <div class="g-unit g-first"><div class="id-chart-footer-links hide">
# <span class="settings-link">Settings</span> |
# <span class="technicals-link">Technicals</span> |
# <span style="white-space:nowrap;">
# <img alt="Link to chart icon." class="linktochart-img SP_link" hight="9" src="/finance/s/m4C5KaofCbA/images/cleardot.gif" width="16"/>
# <span class="linktochart-link">
# Link to this view</span>
# </span>
# </div></div>
# <div class="g-unit">
# <span class="chart-dis">Volume delayed by 15 mins.<br>Prices are not from all markets.<br>Sources include SIX.<br>
# </br></br></br></span>
# </div>
# </div>
# </div>
# <script>
# var _minZoomDays = 1;
# var _minZoomDaysNoIntraDay = _minZoomDays;
# var _timeZoneOffset = '-18000';
# _chartConfigObject = {};
# _chartConfigObject.hasVolume = _displayVolume;
# _chartConfigObject.hasNews = true;
# _chartConfigObject.hasExtendedHours = true;
# _chartConfigObject.hasDefaultZoomSetting = true;
# _chartConfigObject.hasVerticalScaleSetting = true;
# _chartConfigObject.displayVolume = 'true';
# _chartConfigObject.displayNewsPins = 'true';
# _chartConfigObject.displayDividends = 'true';
# _chartConfigObject.displaySplits = 'true';
# _chartConfigObject.displayExtendedHours = 'false';
# _chartConfigObject.enableCustomDateEntry = true
# _chartConfigObject.defaultZoomDays = '3';
# _chartConfigObject.snapping = false;
# _chartConfigObject.verticalScaling = 'maximized';
# _chartConfigObject.sparklineType = 'dynamic';
# // set _minZoomDays and _minZoomDaysNoIntraDay in each page before emit the
# // chart to passing the value to chart, otherwise default value will be use.
# _chartConfigObject.minZoomDaysNormal = _minZoomDays;
# _chartConfigObject.minZoomDaysNoIntraDay = _minZoomDaysNoIntraDay;
# _chartConfigObject.enableIndicator = true;
# _chartConfigObject.companyId = '22144';
# _chartConfigObject.enableRealtimeChart = true;
# _chartConfigObject.isMarketOpenState = 0;
# _chartConfigObject.stateRemainingMinutes = 873;
# _chartConfigObject.delayedMinutes = 0;
# _chartConfigObject.delayedMinutes = Math.max(
# _chartConfigObject.delayedMinutes,
# 15);
# _chartConfigObject.enableChartTypeSetting = true;
# _chartConfigObject.lineStyle = 'IntervalBasedLine';
# _chartConfigObject.defaultInterval = '86400';
# _chartConfigObject.enableIndicatorSetting = true;
# _chartConfigObject.biasSetting = '';
# _chartConfigObject.emaSetting = '';
# _chartConfigObject.kdjSetting = '';
# _chartConfigObject.macdSetting = '';
# _chartConfigObject.rsiSetting = '';
# _chartConfigObject.smaSetting = '';
# _chartConfigObject.vmaSetting = '';
# _chartConfigObject.cciSetting = '';
# _chartConfigObject.williamsPercentRSetting = '';
# _chartConfigObject.bollingerBandsSetting = '';
# _chartConfigObject.fastStochasticSetting = '';
# _chartConfigObject.slowStochasticSetting = '';
# _chartConfigObject.expandButtonEnabled = true;
# _chartConfigObject.companyCurrency = 'USD';
# _chartConfigObject.displayDividendsUnits = 'true';
# _external_target = "";
# _emitFlashChart(
# "/finance/s/n-VxNKK74DU/chart9.swf?hl=en&gl=us",
# _ticker, _chartConfigObject,"http:\x2F\x2Fwww.google.com:80");
# </script>
# <noscript>
# <div id="image_chart" style="display:block;">
# <table>
# <tr><td align="left" class="itxt">
# </td></tr>
# <tr><td>
# <img alt="Chart." height="322" src="/finance/getchart?q=AAPL&amp;x=NASD&amp;p=3d&amp;i=240&amp;ei=25jZWNCaJoSje5bbhcgJ" width="500">
# </img></td></tr>
# </table>
# </div>
# </noscript>
# <div style="height:1em;"></div>
# </div>
# </div>
# <div id="ad2">
# <div class="invisible" id="ad2-label">Advertisement</div>
# <div class="id-ad2-target" id="ad2-target"></div>
# </div>
# </div>
# <div class="g-c sfe-break-right">
# <div class="id-related hide" id="related">
# <div class="hdg">
# <div class="float">
# <h3>Related companies</h3>
# </div>
# </div>
# <div>
# <div class="g-section g-tpl-50-50 g-split gf-control">
# <div class="g-unit g-first">
# Show:
# <select class="id-related-select" id="related-select">
# <option value="mrq">
# Most Recent Quarter
# </option>
# <option selected="" value="mra">
# Most Recent Annual
# </option>
# </select>
# </div>
# <div class="g-unit">
# <span class="id-related-edit-col linkbtn">Add or remove columns</span>
# <button class="id-related-save" style="display:none">Save changes</button>
# <button class="id-related-cancel" style="display:none">Cancel</button>
# </div>
# </div>
# </div>
# <div class="id-related-table gf-table-scroll-x jfk-scrollbar" style="padding-bottom:15px;">
# </div>
# <div class="sfe-section">
# <div class="g-section g-tpl-50-50 g-split">
# <div class="g-unit g-first">Sector: <a href="?catid=us-TRBC:57&amp;ei=25jZWNCaJoSje5bbhcgJ" id="sector">Technology</a> &gt; Industry: <a href="?catid=us-TRBC:5710601010&amp;ei=25jZWNCaJoSje5bbhcgJ">Computer Hardware - NEC</a>
# </div><div class="g-unit">
# <a href="//www.google.com/url?source=finance&amp;q=http%3A%2F%2Fwww.factset.com%2Fdata%2Ffactset_data%2Findustry-and-sector&amp;ei=25jZWNCaJoSje5bbhcgJ&amp;usg=AFQjCNFjah4z1jvFZ4SaZESHB1TTNXvdGw">More from FactSet »</a>
# </div>
# </div>
# </div>
# </div>
# <div class="id-reorder" id="reorder"><div class="mid-reorder">
# <div id="blogs-section">
# </div>
# <div id="summary-section">
# <div id="summary">
# <div class="hdg"><div class="float">
# <h3>Description</h3></div>
# <div class="gf-reorder-btn SP_menu_button"></div>
# </div>
# <div class="sfe-section">
# <div class="companySummary">
# Apple Inc. (Apple) designs, manufactures and markets mobile communication and media devices, personal computers, and portable digital music players, and a variety of related software, services, peripherals, networking solutions, and third-party digital content and applications. The Company's products and services include iPhone, iPad, Mac, iPod, Apple TV, a portfolio of consumer and professional software applications, the iOS and OS X operating systems, iCloud, and a variety of accessory, service and support offerings. The Company also delivers digital content and applications through the iTunes Store, App StoreSM, iBookstoreSM, and Mac App Store. The Company distributes its products worldwide through its retail stores, online stores, and direct sales force, as well as through third-party cellular network carriers, wholesalers, retailers, and value-added resellers. In February 2012, the Company acquired app-search engine Chomp.
# <div class="sfe-break-top">
# <a href="//www.google.com/url?source=finance&amp;q=http%3A%2F%2Fstocks.us.reuters.com%2Fstocks%2FfullDescription.asp%3Frpc%3D66%26symbol%3DAAPL.O&amp;ei=25jZWNCaJoSje5bbhcgJ&amp;usg=AFQjCNHMUeeK6fuDZ1kE0uw_ZfVeuJcdCg" id="m-rprofile">
# More from Reuters »
# </a></div>
# </div>
# </div>
# </div>
# </div><script>_tck('aft');</script>
# <div id="mgmt-section">
# <div id="management" style="margin-bottom:1.5em;">
# <div class="hdg"><div class="float">
# <h3>Officers and directors</h3></div>
# <div class="gf-reorder-btn SP_menu_button"></div>
# </div>
# <div class="sfe-section">
# <table class="id-mgmt-table" width="100%"><tbody>
# <tr>
# <td class="p linkbtn">Art D. Levinson Ph.D.
# <td class="i">
# <td class="t">Independent Chairman of the Board
# </td></td></td></tr>
# <tr style="display:none;">
# <td><img align="right" border="0" height="1" width="1">
# <td class="i">
# <td class="t">
# Age: 66<br>
# <a class="e-p" href="//www.google.com/url?source=finance&amp;q=http%3A%2F%2Fwww.reuters.com%2Ffinance%2Fstocks%2FofficerProfile%3Fsymbol%3DAAPL.O%26officerId%3D156560&amp;ei=25jZWNCaJoSje5bbhcgJ&amp;usg=AFQjCNHuQn0pNSIwKfbEMMklmNmNpQtZ1A">
# Bio &amp; Compensation
# </a> - <font color="#606060">Reuters</font><br>
# <tr class="grey-top">
# <td class="p linkbtn">Timothy D. Cook
# <td class="i">
# <td class="t">Chief Executive Officer, Director
# </td></td></td></tr>
# <tr style="display:none;">
# <td><img align="right" border="0" height="1" width="1">
# <td class="i">
# <td class="t">
# Age: 56<br>
# <a class="e-p" href="//www.google.com/url?source=finance&amp;q=http%3A%2F%2Fwww.reuters.com%2Ffinance%2Fstocks%2FofficerProfile%3Fsymbol%3DAAPL.O%26officerId%3D88090&amp;ei=25jZWNCaJoSje5bbhcgJ&amp;usg=AFQjCNEbqZXVr2W7DGrYdEDbGvJQuwnnRA">
# Bio &amp; Compensation
# </a> - <font color="#606060">Reuters</font><br>
# <a class="e-t" href="//www.google.com/url?source=finance&amp;q=http%3A%2F%2Fbiz.yahoo.com%2Ft%2F15%2F6289.html&amp;ei=25jZWNCaJoSje5bbhcgJ&amp;usg=AFQjCNGbqAW-y_u8aE2B6xy5EpqAEEMB-Q">Trading Activity</a> - <font color="#606060">Yahoo Finance</font><br>
# <tr class="grey-top">
# <td class="p linkbtn">Luca Maestri
# <td class="i">
# <td class="t">Chief Financial Officer, Senior Vice President, Principal Accounting Officer
# </td></td></td></tr>
# <tr style="display:none;">
# <td><img align="right" border="0" height="1" width="1">
# <td class="i">
# <td class="t">
# Age: 53<br>
# <a class="e-p" href="//www.google.com/url?source=finance&amp;q=http%3A%2F%2Fwww.reuters.com%2Ffinance%2Fstocks%2FofficerProfile%3Fsymbol%3DAAPL.O%26officerId%3D2486890&amp;ei=25jZWNCaJoSje5bbhcgJ&amp;usg=AFQjCNEYva70mqMYW18LexSaerh66Ilx5w">
# Bio &amp; Compensation
# </a> - <font color="#606060">Reuters</font><br>
# <tr class="grey-top">
# <td class="p linkbtn">Jeff Williams
# <td class="i">
# <td class="t">Chief Operating Officer
# </td></td></td></tr>
# <tr style="display:none;">
# <td><img align="right" border="0" height="1" width="1">
# <td class="i">
# <td class="t">
# Age: 53<br>
# <a class="e-p" href="//www.google.com/url?source=finance&amp;q=http%3A%2F%2Fwww.reuters.com%2Ffinance%2Fstocks%2FofficerProfile%3Fsymbol%3DAAPL.O%26officerId%3D1541701&amp;ei=25jZWNCaJoSje5bbhcgJ&amp;usg=AFQjCNFKQk65lQ6_SMuZU7ezm1im_C_Z8g">
# Bio &amp; Compensation
# </a> - <font color="#606060">Reuters</font><br>
# <tr class="grey-top">
# <td class="p linkbtn">Durward Bruce Sewell
# <td class="i">
# <td class="t">Senior Vice President, General Counsel, Secretary
# </td></td></td></tr>
# <tr style="display:none;">
# <td><img align="right" border="0" height="1" width="1">
# <td class="i">
# <td class="t">
# Age: 58<br>
# <a class="e-p" href="//www.google.com/url?source=finance&amp;q=http%3A%2F%2Fwww.reuters.com%2Ffinance%2Fstocks%2FofficerProfile%3Fsymbol%3DAAPL.O%26officerId%3D1396053&amp;ei=25jZWNCaJoSje5bbhcgJ&amp;usg=AFQjCNFTSvuxgCLcuLwSRCugrJeeqihu7w">
# Bio &amp; Compensation
# </a> - <font color="#606060">Reuters</font><br>
# <tr class="grey-top">
# <td class="p linkbtn">Phil Schiller
# <td class="i">
# <td class="t">Senior Vice President - Worldwide Marketing
# </td></td></td></tr>
# <tr style="display:none;">
# <td><img align="right" border="0" height="1" width="1">
# <td class="i">
# <td class="t">
# Age: 56<br>
# <a class="e-p" href="//www.google.com/url?source=finance&amp;q=http%3A%2F%2Fwww.reuters.com%2Ffinance%2Fstocks%2FofficerProfile%3Fsymbol%3DAAPL.O%26officerId%3D346990&amp;ei=25jZWNCaJoSje5bbhcgJ&amp;usg=AFQjCNH36LjbNmDfzpZh3mp71xULxKhksQ">
# Bio &amp; Compensation
# </a> - <font color="#606060">Reuters</font><br>
# <tr class="grey-top">
# <td class="p linkbtn">Angela J. Ahrendts
# <td class="i">
# <td class="t">Senior Vice President - Retail and Online Stores
# </td></td></td></tr>
# <tr style="display:none;">
# <td><img align="right" border="0" height="1" width="1">
# <td class="i">
# <td class="t">
# Age: 56<br>
# <a class="e-p" href="//www.google.com/url?source=finance&amp;q=http%3A%2F%2Fwww.reuters.com%2Ffinance%2Fstocks%2FofficerProfile%3Fsymbol%3DAAPL.O%26officerId%3D2581904&amp;ei=25jZWNCaJoSje5bbhcgJ&amp;usg=AFQjCNHczOvQ29b3lDQsNFJv8Q_nFrr_Mw">
# Bio &amp; Compensation
# </a> - <font color="#606060">Reuters</font><br>
# <tr class="grey-top">
# <td class="p linkbtn">Eddy Cue
# <td class="i">
# <td class="t">Senior Vice President - Internet Software and Services
# </td></td></td></tr>
# <tr style="display:none;">
# <td><img align="right" border="0" height="1" width="1">
# <td class="i">
# <td class="t">
# Age: 53<br>
# <a class="e-p" href="//www.google.com/url?source=finance&amp;q=http%3A%2F%2Fwww.reuters.com%2Ffinance%2Fstocks%2FofficerProfile%3Fsymbol%3DAAPL.O%26officerId%3D1677766&amp;ei=25jZWNCaJoSje5bbhcgJ&amp;usg=AFQjCNFtJdaD5u5rk4h4f5X5mt0JOIFRnA">
# Bio &amp; Compensation
# </a> - <font color="#606060">Reuters</font><br>
# <tr class="grey-top">
# <td class="p linkbtn">Craig Federighi
# <td class="i">
# <td class="t">Senior Vice President - Software Engineering
# </td></td></td></tr>
# <tr style="display:none;">
# <td><img align="right" border="0" height="1" width="1">
# <td class="i">
# <td class="t">
# Age: 47<br>
# <a class="e-p" href="//www.google.com/url?source=finance&amp;q=http%3A%2F%2Fwww.reuters.com%2Ffinance%2Fstocks%2FofficerProfile%3Fsymbol%3DAAPL.O%26officerId%3D1768087&amp;ei=25jZWNCaJoSje5bbhcgJ&amp;usg=AFQjCNF98qqCKtdakDT19vKFOBH24gJgUw">
# Bio &amp; Compensation
# </a> - <font color="#606060">Reuters</font><br>
# <tr class="grey-top">
# <td class="p linkbtn">Daniel J. Riccio Jr
# <td class="i">
# <td class="t">Senior Vice President - Hardware Engineering
# </td></td></td></tr>
# <tr style="display:none;">
# <td><img align="right" border="0" height="1" width="1">
# <td class="i">
# <td class="t">
# Age: 54<br>
# <a class="e-p" href="//www.google.com/url?source=finance&amp;q=http%3A%2F%2Fwww.reuters.com%2Ffinance%2Fstocks%2FofficerProfile%3Fsymbol%3DAAPL.O%26officerId%3D1747873&amp;ei=25jZWNCaJoSje5bbhcgJ&amp;usg=AFQjCNHGAMCvE2SXG_Yl2d9bhy62X_DTlw">
# Bio &amp; Compensation
# </a> - <font color="#606060">Reuters</font><br>
# </br></br></td></td></img></td></tr></br></br></td></td></img></td></tr></br></br></td></td></img></td></tr></br></br></td></td></img></td></tr></br></br></td></td></img></td></tr></br></br></td></td></img></td></tr></br></br></td></td></img></td></tr></br></br></td></td></img></td></tr></br></br></br></td></td></img></td></tr></br></br></td></td></img></td></tr></tbody></table>
# <div class="gb">
# <a href="//www.google.com/url?source=finance&amp;q=http%3A%2F%2Fstocks.us.reuters.com%2Fstocks%2FofficersDirectors.asp%3Fsymbol%3DAAPL.O%26WTmodLOC%3DC4-Officers-5&amp;ei=25jZWNCaJoSje5bbhcgJ&amp;usg=AFQjCNGI8Ne-vhzIUSDbVGLSbGOFLrhPnw">
# Full list on Reuters »</a></div>
# </div>
# </div>
# </div>
# </div></div>
# </div>
# </div>
# </div>
# </div>
# </div></div></div></div></div><div id="gf-foot"><div class="fjfe-footer-links" id="fjfe-edition-links">Google Finance Beta available in: <a class="fjfe-edition-link" href="http://www.google.com.hk/finance?ei=25jZWNCaJoSje5bbhcgJ">Hong Kong</a> - <a class="fjfe-edition-link" href="http://www.google.ca/finance?ei=25jZWNCaJoSje5bbhcgJ">Canada</a> - <a class="fjfe-edition-link" href="http://www.google.com/finance?ei=25jZWNCaJoSje5bbhcgJ">U.S.</a> - <a class="fjfe-edition-link" href="http://www.google.com.hk/finance?hl=zh-CN&amp;ei=25jZWNCaJoSje5bbhcgJ">China</a> - <a class="fjfe-edition-link" href="http://www.google.co.uk/finance?ei=25jZWNCaJoSje5bbhcgJ">U.K.</a></div><p class="fjfe-footer-disclaimer">Information is provided "as is" and solely for informational purposes, not for trading purposes or advice, and may be delayed.<br>To see all exchange delays, please <a class="fjfe-secondary-link fjfe-no-sticky-params" href="http://www.google.com/intl/en/googlefinance/disclaimer/?ei=25jZWNCaJoSje5bbhcgJ"> see disclaimer</a>.</br></p><div class="fjfe-footer-links">©2017 Google - <a href="http://www.google.com?hl=en&amp;ei=25jZWNCaJoSje5bbhcgJ">Google Home</a> - <a href="http://googlefinanceblog.blogspot.com?ei=25jZWNCaJoSje5bbhcgJ">Blog</a> - <a href="http://support.google.com/finance?hl=en&amp;ei=25jZWNCaJoSje5bbhcgJ">Help</a> - <a href="http://support.google.com/finance?ctx=report&amp;hl=en&amp;ei=25jZWNCaJoSje5bbhcgJ&amp;exch=NASDAQ&amp;sym=AAPL">Report a Problem</a> - <a href="http://www.google.com/intl/en/policies/privacy/?ei=25jZWNCaJoSje5bbhcgJ">Privacy Policy</a> - <a href="http://www.google.com/intl/en/policies/terms/?ei=25jZWNCaJoSje5bbhcgJ">Terms of Service</a></div></div>
# <script>
# var _chartConfigObject;
# var _cleardot;
# var _companyName;
# var _eventid = '25jZWNCaJoSje5bbhcgJ';
# var _expid;
# var _external_target;
# var _localDomain = 'www.google.com';
# var _minZoomDays;
# var _minZoomDaysNoIntraDay;
# var _prefs;
# var _ticker;
# var _urlSuffix;
# _setStickyUrlParams("ei=25jZWNCaJoSje5bbhcgJ");
# if (_s_Store) {
# _s_Store._allowMatchAdvancedSearch = true;
# var _fieldToDisplayNameMap = {GrossMargin:"Gross margin&nbsp;(%)",Return1Week:"1w return",Return156Week:"156w return",NextYearEPS:"Next year EPS",LTDebtToAssetsYear:"LT debt/assets (Recent&nbsp;yr)&nbsp;(%)",RevenueGrowthRate5Years:"5y revenue growth rate",EarningsAfterTaxes:"Earnings after taxes",DividendPerShare:"Div per share",MarketCap:"Market cap",NetProfitMarginPercent:"Net profit margin&nbsp;(%)",Float:"Float",EarningsBeforeTaxes:"Earnings before taxes",QuotePercChange:"Quote change&nbsp;(%)",TotalDebtToEquityYear:"Total debt/equity (Recent&nbsp;yr)&nbsp;(%)",TotalDebtToCapitalQuarter:"Total debt/capital (Recent&nbsp;qtr)&nbsp;(%)",LTDebtToCapitalQuarter:"LT debt/capital (Recent&nbsp;qtr)&nbsp;(%)",EPSGrowthRate10Years:"10y EPS growth rate",Beta:"Beta",ReturnOnAssetsPTM:"Return on assets (PTM)&nbsp;(%)",CapitalGain:"Capital gain",BetaDown:"Beta down from RAS",IncomeDividend:"Income dividend",RevenueGrowthRate10Years:"10y revenue growth rate",MarketCapShareBasis:"Market cap share basis",IAD:"Div rate indicated annual",Return4Week:"4w return",Price150DayAverage:"150d avg price",EPSGrowthRate5Years:"5y EPS growth rate",ReturnOnAssetsTTM:"Return on assets (TTM)&nbsp;(%)",TotalDebtToAssetsYear:"Total debt/assets (Recent&nbsp;yr)&nbsp;(%)",Volume:"Volume",DividendRecentQuarter:"Div recent quarter",CurrentRatioYear:"Current ratio",Low52Week:"52w low",ExpenseRatio:"Expense ratio",Price13WeekPercChange:"13w&nbsp;price change&nbsp;(%)",Price1DayPercChange:"1d&nbsp;price change&nbsp;(%)",ReturnOnEquity5Years:"Return on equity (5&nbsp;yr&nbsp;avg)&nbsp;(%)",TotalDebtToCapitalYear:"Total debt/capital (Recent&nbsp;yr)&nbsp;(%)",TotalDebtToAssetsQuarter:"Total debt/assets (Recent&nbsp;qtr)&nbsp;(%)",NavChange:"Nav change",OperatingMargin:"Operating margin&nbsp;(%)",DPSRecentYear:"Div per share (Recent&nbsp;yr)",ANI:"Earnings after taxes (Recent&nbsp;yr)",AverageVolume:"Average volume",High52Week:"52w high",Return13Week:"13w return",PriceToCashFlowPerShare:"Price to cash flow per share",ATAXRATE:"Tax rate (Recent&nbsp;yr)",Price26WeekPercChange:"26w&nbsp;price change&nbsp;(%)",QuoteChange:"Quote change",NetIncomeChangePerc:"Net income change&nbsp;(%)",ReturnOnInvestment5Years:"Return on investment (5&nbsp;yr&nbsp;avg)&nbsp;(%)",PE:"P/E ratio",ReturnOnInvestmentYear:"Return on investment (Recent&nbsp;yr)&nbsp;(%)",Price200DayAverage:"200d avg price",DividendNextQuarter:"Div next quarter",EBITD:"EBITDA",PriceYTDPercChange:"YTD&nbsp;price change&nbsp;(%)",ReturnOnInvestmentTTM:"Return on investment (TTM)&nbsp;(%)",NavChangePercent:"Nav change&nbsp;(%)",EBITDMargin:"EBITDA margin&nbsp;(%)",LTDebtToEquityQuarter:"LT debt/equity (Recent&nbsp;qtr)&nbsp;(%)",BetaRAS:"Beta from RAS",PriceSales:"Price to sales",NetAssets:"Net assets",ReturnOnEquityTTM:"Return on equity (TTM)&nbsp;(%)",CashPerShareYear:"Cash/share",ReturnOnAssets5Years:"Return on assets (5&nbsp;yr&nbsp;avg)&nbsp;(%)",ReturnDay:"1d return",Return52Week:"52w return",ForwardPE1Year:"1y fwd P/E",NetIncomeGrowthRate5Years:"5y net income growth rate",DividendYield:"Div yield&nbsp;(%)",Dividend:"Div from cash flow",BetaUp:"Beta up from RAS",LTDebtToCapitalYear:"LT debt/capital (Recent&nbsp;yr)&nbsp;(%)",nprice:"Price from RAS",Return260Week:"260w return",ReturnOnEquityQuarter:"Return on equity (Recent&nbsp;qtr)&nbsp;(%)",ACOGS:"Cost of goods sold",LTDebtToAssetsQuarter:"LT debt/assets (Recent&nbsp;qtr)&nbsp;(%)",PriceToBook:"Price to book",LTDebtToEquityYear:"LT debt/equity (Recent&nbsp;yr)&nbsp;(%)",ReturnYTD:"Return YTD",ReturnOnEquityYear:"Return on equity (Recent&nbsp;yr)&nbsp;(%)",ReturnOnAssetsQuarter:"Return on assets (Recent&nbsp;qtr)&nbsp;(%)",TotalDebtToEquityQuarter:"Total debt/equity (Recent&nbsp;qtr)&nbsp;(%)",NavPrior:"Nav prior",AINTCOV:"Interest coverage",EPS:"EPS",ReturnOnInvestmentQuarter:"Return on investment (Recent&nbsp;qtr)&nbsp;(%)",QuoteLast:"Last price",Price50DayAverage:"50d avg price",Price4WeekPercChange:"4w&nbsp;price change&nbsp;(%)",ReturnOnAssetsYear:"Ret ...
# _s_Store._asStore._addStrings(_fieldToDisplayNameMap);
# }
# if (_s_Store) {
# _s_Store._allowMultipleInBox = true;
# }
# _regOnLoad(onCompanyLoad);
# </script>
# </input></div></div><script>var googlefinance = {i: ["f.b.id","",null,0,"",0,null,["f.b.cf","9R147Dhnn8c.en_US.",0],[],1,[],"25jZWNCaJoSje5bbhcgJ","www.google.com","b7okh-xckcpYqpBUd9NQsyyzboM:1490655451781",1]}; GF_domReady = 1;</script></body></html>

# %%
b.prettify() # will print the html nicely
# Out:
# u'<!DOCTYPE html>\n<html>\n <head>\n  <script>\n   (function(){(function(){function e(a){this.t={};this.tick=function(a,c,b){var d=void 0!=b?b:(new Date).getTime();this.t[a]=[d,c];if(void 0==b)try{window.console.timeStamp("CSI/"+a)}catch(h){}};this.tick("start",null,a)}var a,d;window.performance&&(d=(a=window.performance.timing)&&a.responseStart);var f=0<d?new e(d):new e;window.jstiming={Timer:e,load:f};if(a){var c=a.navigationStart;0<c&&d>=c&&(window.jstiming.srt=d-c)}if(a){var b=window.jstiming.load;0<c&&d>=c&&(b.tick("_wtsrt",void 0,c),b.tick("wtsrt_","_wtsrt",\nd),b.tick("tbsd_","wtsrt_"))}try{a=null,window.chrome&&window.chrome.csi&&(a=Math.floor(window.chrome.csi().pageT),b&&0<c&&(b.tick("_tbnd",void 0,window.chrome.csi().startE),b.tick("tbnd_","_tbnd",c))),null==a&&window.gtbExternal&&(a=window.gtbExternal.pageT()),null==a&&window.external&&(a=window.external.pageT,b&&0<c&&(b.tick("_tbnd",void 0,window.external.startE),b.tick("tbnd_","_tbnd",c))),a&&(window.jstiming.pt=a)}catch(g){}})();}).call(this);\n  </script>\n  <title>\n   Apple Inc.: NASDAQ:AAPL quotes &amp; news - Google Finance\n  </title>\n  <meta content="Get detailed financial information on Apple Inc. (NASDAQ:AAPL) including real-time stock quotes, historical charts &amp; financial news, all for free!" name="Description">\n   <meta content="IE=10" http-equiv="X-UA-Compatible">\n    <link href="http://www.google.com/finance?cid=22144" rel="canonical">\n     <link href="/finance/f/finance_us-1489929081.css" rel="stylesheet" type="text/css">\n      <link href="/_/scs/finance-static/_/ss/k=finance.a.x7heix82rby5.L.W.O/d=0/rs=AGHGApFPN2TpOk8r5vkQgPd47Zv7Pkrwuw" rel="stylesheet" type="text/css">\n       <link href="/finance/favicon.ico" rel="icon" type="image/vnd.microsoft.icon">\n        <style>\n         #gbar,#guser{font-size:13px;padding-right:8px;padding-top:4px !important;}#gbar{padding-left:8px;height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;position:absolute;top:24px;width:100%}@media all{.gb1{height:22px;margin-right:.5em;vertical-align:top}#gbar{float:left}}a.gb1,a.gb4{text-decoration:underline !important}a.gb1,a.gb4{color:#00c !important}.gbi .gb4{color:#dd8e27 !important}.gbf .gb4{color:#900 !important}\n        </style>\n        <script>\n        </script>\n        <script async="" defer="" src="//www.google.com/insights/consumersurveys/async_survey?site=xusttduenzseze54mcajwbd6sq">\n        </script>\n        <script>\n         function _rpt() {}\n      function _tck() {}\n        </script>\n        <script>\n         (function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){\n    (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\n    m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n    })(window,document,\'script\',\'//www.google-analytics.com/analytics.js\',\'ga\');\n\n    ga(\'create\', \'UA-40765809-1\', {\n      \'allowLinker\': true,\n      \'cookiePath\': \'/finance\'\n    });\n    ga(\'send\', \'pageview\');\n        </script>\n       </link>\n      </link>\n     </link>\n    </link>\n   </meta>\n  </meta>\n </head>\n <body>\n  <div class="fjfe-bodywrapper">\n   <div class="g-doc" id="fjfe-real-body">\n    <input id="hist_state" name="hist_state" style="display:none;" type="text">\n     <iframe class="invfr" id="hist_frame" name="hist_frame" tabindex="-1">\n     </iframe>\n     <iframe class="invfr" src="/_/scs/finance-static/_/js/k=finance.a.en_US.9R147Dhnn8c.O/m=b/rt=h/d=0/rs=AGHGApGszSEHbMoXAq0_ObWO6zwfX-urUw" tabindex="-1">\n     </iframe>\n     <div id="gbar">\n      <nobr>\n       <a class="gb1" href="https://www.google.com/webhp?tab=ew">\n        Search\n       </a>\n       <a class="gb1" href="http://www.google.com/imghp?hl=en&amp;tab=ei">\n        Images\n       </a>\n       <a class="gb1" href="http://maps.google.com/maps?hl=en&amp;tab=el">\n        Maps\n       </a>\n ...

# %%
# find all span tags
b.findAll('span')
#b.find_all('span') for bs4 users
# Out:
# [<span class="gbi" id="gbn"></span>,
#  <span class="gbf" id="gbf"></span>,
#  <span id="gbe"></span>,
#  <span class="fjfe-searchbox-button-wrapper"><span class="fjfe-searchbox-button-wrapper2"><input class="fjfe-searchbox-button" tabindex="2" type="submit" value="Get quotes"/></span></span>,
#  <span class="fjfe-searchbox-button-wrapper2"><input class="fjfe-searchbox-button" tabindex="2" type="submit" value="Get quotes"/></span>,
#  <span class="fjfe-recentquotes-duration">(<a href="//www.google.com/history/optout?hl=en">30 days</a>)</span>,
#  <span class="fjfe-chg-toggle">chg</span>,
#  <span class="fjfe-perc-toggle">%</span>,
#  <span class="pr">\n<span id="ref_22144_l">140.88</span>\n</span>,
#  <span id="ref_22144_l">140.88</span>,
#  <span class="ch bld"><span class="chg" id="ref_22144_c">+0.24</span>\n<span class="chg" id="ref_22144_cp">(0.17%)</span>\n</span>,
#  <span class="chg" id="ref_22144_c">+0.24</span>,
#  <span class="chg" id="ref_22144_cp">(0.17%)</span>,
#  <span class="bld" id="ref_22144_el">140.95</span>,
#  <span class="chg" id="ref_22144_ec">+0.07</span>,
#  <span class="chg" id="ref_22144_ecp">(0.05%)</span>,
#  <span class="dis-large"><nobr>NASDAQ\nreal-time data -\n<a class="dis-large" href="//www.google.com/help/stock_disclaimer.html#realtime">Disclaimer</a>\n</nobr></span>,
#  <span class="settings-link">Settings</span>,
#  <span class="technicals-link">Technicals</span>,
#  <span style="white-space:nowrap;">\n<img alt="Link to chart icon." class="linktochart-img SP_link" hight="9" src="/finance/s/m4C5KaofCbA/images/cleardot.gif" width="16"/>\n<span class="linktochart-link">\nLink to this view</span>\n</span>,
#  <span class="linktochart-link">\nLink to this view</span>,
#  <span class="chart-dis">Volume delayed by 15 mins.<br>Prices are not from all markets.<br>Sources include SIX.<br>\n</br></br></br></span>,
#  <span class="id-related-edit-col linkbtn">Add or remove columns</span>]

# %%
# the pattern we recognized from the website
re_tag = re.compile("ref_\d+_l") 
print re_tag
# Out:
# <_sre.SRE_Pattern object at 0x1115987b0>

# %%
#this tag finds the tag with the price in it!!!!
span_tag = b.find('span', attrs={'id': re_tag}) 
# use find to return THE ONE AND ONLY span tags with an id that matches our regex
# use findAll to find all matches

# %%
quote = span_tag.text
quote
# Out:
# u'140.88'

# %%
##### EXERCISE #####
# Make a method  get_stock_price that takes in ANY stock ticker and grabs the current price
# If the stock ticker doesn't exist, return -1

# %%
def get_stock_price(ticker):
    response = requests.get("http://google.com/finance?q="+ticker)
    parser = BeautifulSoup(response.text, "html.parser")
    pattern = re.compile("ref_\d+_l")
    span_tag = parser.find("span", attrs={"id":pattern})
    if span_tag:
        return span_tag.text
    else:
        return -1

# %%
for ticker in ['ge', 'spy']:
    print '$' + get_stock_price(ticker)
# Out:
# $29.44
# $233.62

# %%
###### UFO #######

# %%
r = requests.get("http://www.nuforc.org/webreports/ndxe201608.html")
b = BeautifulSoup(r.text, 'html.parser')

# %%
# Let's take a look at the first sighting
for tr in b.findAll('tr', attrs = {'valign':'TOP'})[:1]:
    # the findChildren method returns all children underneath it
    for child in tr.findChildren():
        print child.text
# Out:
# 8/31/16 23:40
# 8/31/16 23:40
# 8/31/16 23:40
# Terre Haute
# Terre Haute
# IN
# IN
# Light
# Light
# 10 minutes
# 10 minutes
# Four unidentified moving flashing lights that hovered in place for several minutes. Terre Haute, Indiana
# Four unidentified moving flashing lights that hovered in place for several minutes. Terre Haute, Indiana
# 9/2/16
# 9/2/16

# %%
# OK, it's a bit messy, Let's clean it up
# Looks like the first element is the date, the 4th is the city, 6th if state, 8th is shape (this ones blank)
# 13th is the summary

# %%
ufo_sightings = {
        'Date':[],
        'City':[],
        'State':[],
        'Shape':[],
        'Summary':[]
    }

for tr in b.findAll('tr', attrs = {'valign':'TOP'}):
    # the findChildren method returns all children underneath it
    ufo_sighting_info = []
    for child in tr.findChildren():
        ufo_sighting_info.append(child.text)
    ufo_sightings['Date'].append(ufo_sighting_info[0])
    ufo_sightings['City'].append(ufo_sighting_info[3])
    ufo_sightings['State'].append(ufo_sighting_info[5])
    ufo_sightings['Shape'].append(ufo_sighting_info[7])
    ufo_sightings['Summary'].append(ufo_sighting_info[12])

ufo_sightings
# Out:
# {'City': [u'Terre Haute',
#   u'Corte Madera',
#   u'Malo',
#   u'Arlington',
#   u'Concord',
#   u'Pomona',
#   u'Grants',
#   u'Oklahoma city',
#   u'Shoreview',
#   u'Memphis',
#   u'Holden',
#   u'Columbus',
#   u'Anchorage',
#   u'Spring',
#   u'Menifee',
#   u'Tempe',
#   u'Tempe',
#   u'Zeeland',
#   u'Ellington',
#   u'Greeley',
#   u'Pittsburgh',
#   u'New York City (Bronx)',
#   u'Hyrum',
#   u'Fayetteville',
#   u'Dana Point',
#   u'Utica',
#   u'West Chicago',
#   u'Ladson',
#   u'Boulder',
#   u'Seabrook',
#   u'New York',
#   u'Herriman',
#   u'Newport News',
#   u'Pittsfielsd',
#   u'Easton',
#   u'Carrollton',
#   u'Arlington',
#   u'Virginia Beach',
#   u'Jacksonville',
#   u'Surf City',
#   u'Portland',
#   u'St. Louis',
#   u'Pomona',
#   u'Columbus',
#   u'Cody',
#   u'Hermitage',
#   u'New York City (Bronx)',
#   u'New Castle',
#   u'Toronto (Canada)',
#   u'Newmarket (Canada)',
#   u'Raeford',
#   u'Juneau',
#   u'Runnemede',
#   u'Williamsburg',
#   u'Wakefield',
#   u'Santa Rosa',
#   u'Petaluma',
#   u'Santa Rosa',
#   u'Pottstown',
#   u'Piscataway',
#   u'Piscataway',
#   u'Sylmar',
#   u'Albuquerque',
#   u'Northampton (UK/England)',
#   u'Camden',
#   u'Old Lyme',
#   u'White House',
#   u'Surf City',
#   u'Detroit',
#   u'Sarnia (Canada)',
#   u'Spencerport',
#   u'Malverne',
#   u'Camden',
#   u'Lawrence',
#   u'Jefferson',
#   u'Hollister',
#   u'Caledonia',
#   u'Ellington',
#   u'Miami Beach',
#   u'Surf City',
#   u'Greensburg',
#   u'Kingsport',
#   u'Altamonte Springs',
#   u'Laplata',
#   u'Macomb',
#   u'Gilbertsville',
#   u'San Antonio',
#   u'Stevens Point',
#   u'Visalia',
#   u'Wilson',
#   u'Waterton (Canada)',
#   u'Astoria',
#   u'Cedar Park',
#   u'Pacific Palisades',
#   u'Aloha',
#   u'Canton',
#   u'Kennesaw',
#   u'Sheffield',
#   u'Harrogate',
#   u'Cicero',
#   u'Goldsboro',
#   u'Blackshear',
#   u'McConnellsburg',
#   u'Lakewood',
#   u'Mosca',
#   u'Thornton',
#   u'Whitehall',
#   u'Rantoul',
#   u'Emporium',
#   u'Rantoul',
#   u'SeaTac Airport',
#   u'Recife',
#   u'Lakeland',
#   u'Murrieta',
#   u'Syracuse',
#   u'Walnut Creek (area off I-680)',
#   u'Cleveland (Oneida Lake)',
#   u'Mobile',
#   u'Holiday',
#   u'Baytown',
#   u'Rutland (near; Griffith Lake)',
#   u'Seminole',
#   u'Holland',
#   u'Carver',
#   u'Ocean City',
#   u'East Providence',
#   u'Palm Harbor',
#   u'Charleston',
#   u'Gila Bend',
#   u'Kansas City/Columbia (between)',
#   u"Comer's Rock (near)",
#   u'Hilliard',
#   u'Boise',
#   u'Ann Arbor',
#   u'Philadelphia',
#   u'Hossegor (France)',
#   u'Prescott Valley',
#   u'Montreal West (Canada)',
#   u'Westwood',
#   u'Stoddard',
#   u'Avalon',
#   u'Oak Grove',
#   u'Ann Arbor',
#   u'Montrose',
#   u'Mantua',
#   u'Sedona',
#   u'Swedesboro',
#   u'Santa Ana',
#   u'Elkhorn',
#   u'Perris',
#   u'Perris',
#   u'Mauriceville/Buna',
#   u'Newburg',
#   u'Rheden (Netherlands)',
#   u'Hibbing',
#   u'Whitehorse (Canada)',
#   u'Silverton',
#   u'Silverton',
#   u'Erie',
#   u'Columbia',
#   u'Gillette',
#   u'St. Petersburg',
#   u'Asheboro',
#   u'Wellington',
#   u'Obando (Colombia)',
#   u'Milwaukie',
#   u'Little Rock',
#   u'M\xe1laga (Granada)(Spain)',
#   u'Monroe',
#   u'Chicago',
#   u'Windsor',
#   u'Cedar Hills',
#   u'Brockton',
#   u'San Diego (North County)',
#   u'West Pawlet',
#   u'Jamestown',
#   u'Athens',
#   u'Burlington',
#   u'Southport',
#   u'Budapest (Hungary)',
#   u'Gorham',
#   u'South Amboy',
#   u'Hazel Crest',
#   u'Oceanside',
#   u'Los Angeles',
#   u'Michigan City',
#   u'Meridian',
#   u'Atkinson',
#   u'Aberdeen Gardens',
#   u'Lebanon',
#   u'Red Lion',
#   u'Salt Lake City',
#   u'Grass Valley',
#   u'Fort Pierce',
#   u'Curtis Bau',
#   u'Sylvania',
#   u'Gosnell',
#   u'Knoxville',
#   u'Tustin',
#   u'Kokomo',
#   u'Corinna',
#   u'Sun City',
#   u'East Los Angeles',
#   u'Knoxville',
#   u'Pompano Beach',
#   u'Vero Beach',
#   u'Citrus Springs',
#   u'Boca Raton',
#   u'Vero Beach',
#   u'Warren',
#   u'Lake Wales',
#   u'Atlantic City',
#   u'Layton',
#   u'St. Marys',
#   u'Slatington',
#   u'Albany',
#   u'Mesa',
#   u'Maricopa',
#   u'Saint Simons Island',
#   u'Long Beach',
#   u'Los Angeles',
#   u'Waterloo',
#   u'Torrington',
#   u'Perrysburgh',
#   u'Kemp',
#   u'Opelousas',
#   u'Milford',
#   u'Wesley Chapel',
#   u'Northfield',
#   u'Kansas City',
#   u'Los Angeles',
#   u'Gilbert',
#   u'Tygh Valley',
#   u'Bethlehem',
#   u'Baytown',
#   u'Bremerton',
#   u'Port Saint Lucie',
#   u'Elizabethton',
#   u'Gaylord',
#   u'Orange Park',
#   u'Hamlet',
#   u'Amarillo',
#   u'Paphos (Cyprus)',
#   u'White Sands',
#   u'Biglerville',
#   u'Beaverton',
#   u'Snohomish',
#   u'Gaylord',
#   u'Manchester (UK/England)',
#   u'Boise',
#   u'Providence',
#   u'Providence',
#   u'Edison',
#   u'New York City (Manhattan)',
#   u'Cadiz',
#   u'Memphis',
#   u'Cornelius',
#   u'Northglenn',
#   u'Sumter',
#   u'San Diego',
#   u'Boulder',
#   u'Laguna Beach',
#   u'Gilbert',
#   u'Pine island',
#   u'Foster',
#   u'Nashville',
#   u'Marina Del Rey',
#   u'Wassaic',
#   u'Stoughton',
#   u'Ogallala',
#   u'Camden',
#   u'Wheatland',
#   u'Sedro Woolley',
#   u'Nashua',
#   u'Sabattus',
#   u'Vancouver',
#   u'Nantucket',
#   u'Allyn',
#   u'Saratoga',
#   u'Hilliard',
#   u'Rygge (Norway)',
#   u'Vancouver',
#   u'Chester',
#   u'Buford',
#   u'Berea',
#   u'Fargo',
#   u'Denver',
#   u'Jacksonville',
#   u'Bend',
#   u'Bourbonnais',
#   u'Hurricane',
#   u'Madison',
#   u'Elkins (near)',
#   u'Teston (UK/England)',
#   u'Mukwonago',
#   u'Miami (Bal Harbor)',
#   u'Leawood',
#   u'Elizabeth City',
#   u'Alexandria',
#   u'Raleigh',
#   u'Fort Collins',
#   u'Harrisburg',
#   u'Longmont',
#   u'Albany',
#   u'Derby (UK/England)',
#   u'Charlevoix',
#   u'Fairfax',
#   u'Ridgecrest',
#   u'Portland',
#   u'Jackson',
#   u'Lake Roesiger',
#   u'Inkster',
#   u'Albuquerque',
#   u'New York City (Middle Village)',
#   u'Fairfield',
#   u'Kalawana (Sri Lanka)',
#   u'Riverside',
#   u'St. Peters',
#   u'Tijeras',
#   u'Stuart',
#   u'Bayonne',
#   u'Yakima',
#   u'Rio Rancho',
#   u'Parkersburg',
#   u'Oakville (Canada)',
#   u'Reynoldsburg',
#   u'Deltona',
#   u'Interstate 8',
#   u'Indian Trail',
#   u'Lakewood',
#   u'Wilburton',
#   u'Tacoma',
#   u'Kaunakakai',
#   u'Phoenix',
#   u'Wells',
#   u'Kaimuki',
#   u'Lincoln',
#   u'Rochester',
#   u'Sand Springs',
#   u'Gainesville',
#   u'Rochester',
#   u'Golden',
#   u'Three Oaks',
#   u'Carmichael',
#   u'Woonsocket',
#   u'Eagle Point',
#   u'Stone Creek',
#   u'Exeter',
#   u'South Gate',
#   u'Ocean City',
#   u'North Providence',
#   u'Oysterville',
#   u'SeaTac',
#   u'Curlew',
#   u'York',
#   u'Shrewsbury',
#   u'Naches',
#   u'Fort Collins',
#   u'Lawrenceville',
#   u'Lawrenceville',
#   u'New York City (Brooklyn)',
#   u'Salt Lake City',
#   u'Appleton',
#   u'Kennewick',
#   u'Kingston',
#   u'Sharon',
#   u'Chelan',
#   u'Ashland',
#   u'Squamish (Canada)',
#   u'Clinton',
#   u'Florence',
#   u'Antioch',
#   u'Palm Coast',
#   u'Anchorage/Eagle River (between)',
#   u'Morse Mill',
#   u'Ypsilanti',
#   u'Oak Creek',
#   u'Gastonia',
#   u'Oak Lawn',
#   u'Citrus Heights',
#   u'Fort Lauderdale',
#   u'Sand Springs',
#   u'Home',
#   u'Angier',
#   u'Johnson City',
#   u'East Liverpool',
#   u'Framingham',
#   u'Murfreesboro',
#   u'District Heights',
#   u'Lafayette',
#   u'Menifee',
#   u'Avon',
#   u'Colfax',
#   u'Mankato',
#   u'Citrus Heights',
#   u'Durham',
#   u'Conway',
#   u'Detroit',
#   u'Portland',
#   u'Atlanta',
#   u'Bend',
#   u'Pearl City',
#   u'Bel Aire',
#   u'Calpe (Spain)',
#   u'Jackson',
#   u'Castro Valley',
#   u'Pawleys Island',
#   u'Emerald Isle',
#   u'Big Stone Gap',
#   u'Starke',
#   u'Sheridan',
#   u'Washington',
#   u'Washington',
#   u'Wethersfield',
#   u'Bradley Beach',
#   u'Sandy (suburb of SLC)',
#   u'Galion',
#   u'Boise',
#   u'Nampa',
#   u'Anderson',
#   u'Jacksonville',
#   u'Las Cruces',
#   u'Las Vegas',
#   u'Ocean City',
#   u'Longview',
#   u'Wilmington',
#   u'Elliottsburg',
#   u'Cement City',
#   u'Lady Lake',
#   u'Indianapolis',
#   u'Hastings/Revanna Townships',
#   u'Edgerton',
#   u'Antioch',
#   u'Hatton City (Sri Lanka)',
#   u'Yonkers',
#   u'College Park',
#   u'Monte Crist',
#   u'Los Banos',
#   u'Seattle',
#   u'Roanoke',
#   u'Bridgeport',
#   u'Dresden (near)',
#   u'Saugerties',
#   u'Layton',
#   u'Stanton',
#   u'Bemidji',
#   u'Grand Blanc',
#   u'Windham (Catskills)',
#   u'Mt. Lookout',
#   u'Boise',
#   u'New Lenox',
#   u'Nampa',
#   u'Meridian',
#   u'Elyria',
#   u'Bridgeport',
#   u'Boise',
#   u'Garner',
#   u'Overland Park',
#   u'Glendale',
#   u'St. Paul',
#   u'Coweta',
#   u'Freedom',
#   u'Kenmore',
#   u'Mason',
#   u'New Britain',
#   u'New Hope',
#   u'Clinton',
#   u'Oak Hill',
#   u'Lexington',
#   u'Shelby',
#   u'Apopka',
#   u'Del Valle',
#   u'Chincoteague',
#   u'Upper St. Clair',
#   u'Barre',
#   u'Pittsburgh',
#   u'Ludlow',
#   u'Fairborn',
#   u'Kamloops (Canada)',
#   u'Murfreesboro',
#   u'Rosedale',
#   u'Toney',
#   u'Lowell',
#   u'Cold Spring',
#   u'Englewood',
#   u'Pigeon Forge',
#   u'Philmont Scout Ranch',
#   u'Lake Mills',
#   u'Cliffside Park',
#   u'Russia',
#   u'Goose Creek',
#   u'Amite',
#   u'Snoqualmie',
#   u'Pittsburgh',
#   u'Costa Mesa',
#   u'Yarmouth (Canada)',
#   u'Winnemucca',
#   u'Mackinaw City',
#   u'Valparaiso',
#   u'Saylorsburg',
#   u'In flight (Sea of Japan)',
#   u'Carver',
#   u'Dorchester',
#   u'Austin',
#   u'Centereach',
#   u'Clovis',
#   u'Las Vegas',
#   u'Winthrop Harbor',
#   u'Champaign',
#   u'Phoenix',
#   u'Round Rock',
#   u'Portland',
#   u'Mount Gilead',
#   u'Ashville',
#   u'Austin',
#   u'St. Louis',
#   u'St. Louis',
#   u'Houston',
#   u'Pittsburg',
#   u'Puyallup',
#   u'Alexandria (W. Dunbartonshire)(UK/Scotland)',
#   u'Florissant',
#   u'Augusta',
#   u'Hiltons',
#   u'Chico',
#   u'Baltimore',
#   u'Port Colbourne (Ontario)(Canada)',
#   u'Zurich (Switzerland)',
#   u'Milwaukie',
#   u'Shoreline',
#   u'Shelbyville',
#   u'Colorado Springs',
#   u'New Waterford (Canada)',
#   u'Omaha',
#   u'La Vista',
#   u'Old Orchard Beach',
#   u'Jacksonville',
#   u'Jacksonville',
#   u'Blythe',
#   u'Dubuque',
#   u'Mayo (Canada)',
#   u'Menorca (Spain)',
#   u'Lakewood',
#   u'Mountain Home'],
#  'Date': [u'8/31/16 23:40',
#   u'8/31/16 22:00',
#   u'8/31/16 22:00',
#   u'8/31/16 21:00',
#   u'8/31/16 21:00',
#   u'8/31/16 19:46',
#   u'8/31/16 19:38',
#   u'8/31/16 16:45',
#   u'8/31/16 12:00',
#   u'8/31/16 01:38',
#   u'8/30/16 23:57',
#   u'8/30/16 23:56',
#   u'8/30/16 23:08',
#   u'8/30/16 22:30',
#   u'8/30/16 21:50',
#   u'8/30/16 21:45',
#   u'8/30/16 21:40',
#   u'8/30/16 21:00',
#   u'8/30/16 20:45',
#   u'8/30/16 20:30',
#   u'8/30/16 20:00',
#   u'8/30/16 20:00',
#   u'8/30/16 19:59',
#   u'8/30/16 17:40',
#   u'8/30/16 16:00',
#   u'8/30/16 11:30',
#   u'8/30/16 11:00',
#   u'8/30/16 09:50',
#   u'8/30/16 07:40',
#   u'8/30/16 03:00',
#   u'8/30/16 02:45',
#   u'8/29/16 23:39',
#   u'8/29/16 23:00',
#   u'8/29/16 22:00',
#   u'8/29/16 22:00',
#   u'8/29/16 21:30',
#   u'8/29/16 21:28',
#   u'8/29/16 21:00',
#   u'8/29/16 20:45',
#   u'8/29/16 20:26',
#   u'8/29/16 20:25',
#   u'8/29/16 20:00',
#   u'8/29/16 19:00',
#   u'8/29/16 11:55',
#   u'8/29/16 09:30',
#   u'8/29/16 04:00',
#   u'8/29/16 00:20',
#   u'8/28/16 23:00',
#   u'8/28/16 22:00',
#   u'8/28/16 22:00',
#   u'8/28/16 22:00',
#   u'8/28/16 21:40',
#   u'8/28/16 21:35',
#   u'8/28/16 20:45',
#   u'8/28/16 20:00',
#   u'8/28/16 19:50',
#   u'8/28/16 19:30',
#   u'8/28/16 19:30',
#   u'8/28/16 18:00',
#   u'8/28/16 12:16',
#   u'8/28/16 12:16',
#   u'8/28/16 12:00',
#   u'8/28/16 10:30',
#   u'8/28/16 09:30',
#   u'8/28/16 09:00',
#   u'8/28/16 08:57',
#   u'8/27/16 23:15',
#   u'8/27/16 23:00',
#   u'8/27/16 22:45',
#   u'8/27/16 22:15',
#   u'8/27/16 21:25',
#   u'8/27/16 21:05',
#   u'8/27/16 21:00',
#   u'8/27/16 20:20',
#   u'8/27/16 20:15',
#   u'8/27/16 20:14',
#   u'8/27/16 18:45',
#   u'8/27/16 09:00',
#   u'8/27/16 00:15',
#   u'8/26/16 23:30',
#   u'8/26/16 23:00',
#   u'8/26/16 22:40',
#   u'8/26/16 21:25',
#   u'8/26/16 20:45',
#   u'8/26/16 20:30',
#   u'8/26/16 20:15',
#   u'8/26/16 20:00',
#   u'8/26/16 19:31',
#   u'8/26/16 13:00',
#   u'8/26/16 07:00',
#   u'8/26/16 03:00',
#   u'8/25/16 23:00',
#   u'8/25/16 22:15',
#   u'8/25/16 21:35',
#   u'8/25/16 21:00',
#   u'8/25/16 20:58',
#   u'8/25/16 20:45',
#   u'8/25/16 20:15',
#   u'8/25/16 16:15',
#   u'8/25/16 14:00',
#   u'8/25/16 10:30',
#   u'8/25/16 10:00',
#   u'8/25/16 05:40',
#   u'8/25/16 02:20',
#   u'8/24/16 23:30',
#   u'8/24/16 23:30',
#   u'8/24/16 21:45',
#   u'8/24/16 20:30',
#   u'8/24/16 20:30',
#   u'8/24/16 20:15',
#   u'8/24/16 20:00',
#   u'8/24/16 18:20',
#   u'8/24/16 16:00',
#   u'8/24/16 12:20',
#   u'8/24/16 08:00',
#   u'8/24/16 06:45',
#   u'8/24/16 06:31',
#   u'8/24/16 03:45',
#   u'8/24/16 00:00',
#   u'8/23/16 23:30',
#   u'8/23/16 23:00',
#   u'8/23/16 22:54',
#   u'8/23/16 22:20',
#   u'8/23/16 22:07',
#   u'8/23/16 21:40',
#   u'8/23/16 21:30',
#   u'8/23/16 21:00',
#   u'8/23/16 19:30',
#   u'8/23/16 19:00',
#   u'8/23/16 17:30',
#   u'8/23/16 15:30',
#   u'8/23/16 10:30',
#   u'8/23/16 02:00',
#   u'8/22/16 22:30',
#   u'8/22/16 22:26',
#   u'8/22/16 22:23',
#   u'8/22/16 22:15',
#   u'8/22/16 22:06',
#   u'8/22/16 21:50',
#   u'8/22/16 21:30',
#   u'8/22/16 21:25',
#   u'8/22/16 21:00',
#   u'8/22/16 20:27',
#   u'8/22/16 20:15',
#   u'8/22/16 20:00',
#   u'8/22/16 20:00',
#   u'8/22/16 19:00',
#   u'8/22/16 12:25',
#   u'8/22/16 06:00',
#   u'8/22/16 02:49',
#   u'8/22/16 02:25',
#   u'8/22/16 02:00',
#   u'8/22/16 01:17',
#   u'8/22/16 00:30',
#   u'8/22/16 00:30',
#   u'8/22/16 00:00',
#   u'8/21/16 23:00',
#   u'8/21/16 23:00',
#   u'8/21/16 21:40',
#   u'8/21/16 11:24',
#   u'8/21/16 10:58',
#   u'8/21/16 10:00',
#   u'8/21/16 09:00',
#   u'8/21/16 04:15',
#   u'8/21/16 03:00',
#   u'8/21/16 02:45',
#   u'8/21/16 01:01',
#   u'8/20/16 23:45',
#   u'8/20/16 23:00',
#   u'8/20/16 23:00',
#   u'8/20/16 23:00',
#   u'8/20/16 23:00',
#   u'8/20/16 22:57',
#   u'8/20/16 22:50',
#   u'8/20/16 22:30',
#   u'8/20/16 22:30',
#   u'8/20/16 22:25',
#   u'8/20/16 21:52',
#   u'8/20/16 21:45',
#   u'8/20/16 21:15',
#   u'8/20/16 21:10',
#   u'8/20/16 20:45',
#   u'8/20/16 20:22',
#   u'8/20/16 19:32',
#   u'8/20/16 19:14',
#   u'8/20/16 12:00',
#   u'8/20/16 05:00',
#   u'8/20/16 03:30',
#   u'8/19/16 22:45',
#   u'8/19/16 22:10',
#   u'8/19/16 22:05',
#   u'8/19/16 22:00',
#   u'8/19/16 22:00',
#   u'8/19/16 22:00',
#   u'8/19/16 21:45',
#   u'8/19/16 21:00',
#   u'8/19/16 21:00',
#   u'8/19/16 20:49',
#   u'8/19/16 20:30',
#   u'8/19/16 18:56',
#   u'8/19/16 15:35',
#   u'8/19/16 09:30',
#   u'8/19/16 06:55',
#   u'8/19/16 06:30',
#   u'8/19/16 06:30',
#   u'8/19/16 00:55',
#   u'8/19/16 00:54',
#   u'8/19/16 00:54',
#   u'8/19/16 00:53',
#   u'8/19/16 00:00',
#   u'8/18/16 23:55',
#   u'8/18/16 22:40',
#   u'8/18/16 22:30',
#   u'8/18/16 22:10',
#   u'8/18/16 22:00',
#   u'8/18/16 21:45',
#   u'8/18/16 21:00',
#   u'8/18/16 20:37',
#   u'8/18/16 20:30',
#   u'8/18/16 20:23',
#   u'8/18/16 20:20',
#   u'8/18/16 19:00',
#   u'8/18/16 18:00',
#   u'8/18/16 06:00',
#   u'8/18/16 00:00',
#   u'8/17/16 22:50',
#   u'8/17/16 21:30',
#   u'8/17/16 21:30',
#   u'8/17/16 21:30',
#   u'8/17/16 21:00',
#   u'8/17/16 20:40',
#   u'8/17/16 20:00',
#   u'8/17/16 15:00',
#   u'8/17/16 08:15',
#   u'8/17/16 05:00',
#   u'8/16/16 23:40',
#   u'8/16/16 23:00',
#   u'8/16/16 23:00',
#   u'8/16/16 22:15',
#   u'8/16/16 22:00',
#   u'8/16/16 21:30',
#   u'8/16/16 21:30',
#   u'8/16/16 21:00',
#   u'8/16/16 20:48',
#   u'8/16/16 20:15',
#   u'8/16/16 19:00',
#   u'8/16/16 17:00',
#   u'8/16/16 10:15',
#   u'8/16/16 07:12',
#   u'8/16/16 05:30',
#   u'8/16/16 05:30',
#   u'8/16/16 05:30',
#   u'8/16/16 04:10',
#   u'8/16/16 02:47',
#   u'8/16/16 02:20',
#   u'8/15/16 23:45',
#   u'8/15/16 23:15',
#   u'8/15/16 23:00',
#   u'8/15/16 23:00',
#   u'8/15/16 21:36',
#   u'8/15/16 21:15',
#   u'8/15/16 21:00',
#   u'8/15/16 20:05',
#   u'8/15/16 16:00',
#   u'8/15/16 13:00',
#   u'8/15/16 03:10',
#   u'8/14/16 22:45',
#   u'8/14/16 22:40',
#   u'8/14/16 21:30',
#   u'8/14/16 21:30',
#   u'8/14/16 21:00',
#   u'8/14/16 21:00',
#   u'8/14/16 19:45',
#   u'8/14/16 19:00',
#   u'8/14/16 19:00',
#   u'8/14/16 18:00',
#   u'8/14/16 17:00',
#   u'8/14/16 17:00',
#   u'8/14/16 16:30',
#   u'8/14/16 10:30',
#   u'8/14/16 03:00',
#   u'8/14/16 01:57',
#   u'8/14/16 00:00',
#   u'8/14/16',
#   u'8/13/16 00:00',
#   u'8/13/16 23:33',
#   u'8/13/16 23:00',
#   u'8/13/16 22:15',
#   u'8/13/16 22:00',
#   u'8/13/16 21:45',
#   u'8/13/16 21:40',
#   u'8/13/16 21:40',
#   u'8/13/16 21:30',
#   u'8/13/16 21:00',
#   u'8/13/16 20:45',
#   u'8/13/16 19:10',
#   u'8/13/16 13:00',
#   u'8/13/16 06:57',
#   u'8/13/16 05:15',
#   u'8/13/16 05:15',
#   u'8/13/16 04:00',
#   u'8/13/16 03:25',
#   u'8/13/16 02:15',
#   u'8/13/16 00:47',
#   u'8/12/16 23:30',
#   u'8/12/16 23:00',
#   u'8/12/16 23:00',
#   u'8/12/16 23:00',
#   u'8/12/16 22:30',
#   u'8/12/16 22:30',
#   u'8/12/16 21:00',
#   u'8/12/16 21:00',
#   u'8/12/16 21:00',
#   u'8/12/16 20:30',
#   u'8/12/16 20:00',
#   u'8/12/16 19:40',
#   u'8/12/16 19:00',
#   u'8/12/16 19:00',
#   u'8/12/16 16:30',
#   u'8/12/16 16:00',
#   u'8/12/16 14:00',
#   u'8/12/16 13:00',
#   u'8/12/16 12:00',
#   u'8/12/16 10:30',
#   u'8/12/16 08:10',
#   u'8/12/16 07:00',
#   u'8/12/16 04:15',
#   u'8/12/16 04:00',
#   u'8/12/16 03:00',
#   u'8/12/16 03:00',
#   u'8/12/16 03:00',
#   u'8/12/16 02:45',
#   u'8/12/16 02:15',
#   u'8/12/16 02:04',
#   u'8/12/16 02:00',
#   u'8/12/16 01:45',
#   u'8/12/16 01:00',
#   u'8/12/16 00:50',
#   u'8/12/16 00:05',
#   u'8/12/16 00:00',
#   u'8/11/16 23:45',
#   u'8/11/16 23:40',
#   u'8/11/16 23:30',
#   u'8/11/16 23:30',
#   u'8/11/16 23:00',
#   u'8/11/16 23:00',
#   u'8/11/16 22:57',
#   u'8/11/16 22:30',
#   u'8/11/16 22:30',
#   u'8/11/16 22:01',
#   u'8/11/16 22:00',
#   u'8/11/16 22:00',
#   u'8/11/16 22:00',
#   u'8/11/16 22:00',
#   u'8/11/16 22:00',
#   u'8/11/16 22:00',
#   u'8/11/16 21:45',
#   u'8/11/16 21:30',
#   u'8/11/16 21:30',
#   u'8/11/16 21:30',
#   u'8/11/16 21:20',
#   u'8/11/16 21:16',
#   u'8/11/16 20:50',
#   u'8/11/16 20:30',
#   u'8/11/16 20:00',
#   u'8/11/16 20:00',
#   u'8/11/16 20:00',
#   u'8/11/16 19:30',
#   u'8/11/16 19:10',
#   u'8/11/16 18:00',
#   u'8/11/16 14:30',
#   u'8/11/16 09:10',
#   u'8/11/16 07:00',
#   u'8/11/16 01:20',
#   u'8/11/16 01:00',
#   u'8/11/16 00:30',
#   u'8/10/16 23:45',
#   u'8/10/16 23:35',
#   u'8/10/16 23:20',
#   u'8/10/16 23:00',
#   u'8/10/16 23:00',
#   u'8/10/16 22:30',
#   u'8/10/16 22:00',
#   u'8/10/16 21:34',
#   u'8/10/16 21:30',
#   u'8/10/16 21:27',
#   u'8/10/16 21:00',
#   u'8/10/16 20:25',
#   u'8/10/16 18:30',
#   u'8/10/16 11:20',
#   u'8/10/16 05:00',
#   u'8/10/16 03:30',
#   u'8/10/16 02:30',
#   u'8/10/16 01:30',
#   u'8/10/16 01:00',
#   u'8/10/16 00:00',
#   u'8/9/16 23:50',
#   u'8/9/16 23:00',
#   u'8/9/16 23:00',
#   u'8/9/16 22:37',
#   u'8/9/16 22:10',
#   u'8/9/16 21:50',
#   u'8/9/16 21:40',
#   u'8/9/16 12:30',
#   u'8/9/16 04:00',
#   u'8/9/16 03:40',
#   u'8/9/16 00:30',
#   u'8/8/16 23:45',
#   u'8/8/16 23:15',
#   u'8/8/16 22:30',
#   u'8/8/16 22:15',
#   u'8/8/16 22:00',
#   u'8/8/16 22:00',
#   u'8/8/16 21:35',
#   u'8/8/16 21:00',
#   u'8/8/16 20:12',
#   u'8/8/16 19:00',
#   u'8/8/16 18:15',
#   u'8/8/16 17:30',
#   u'8/8/16 14:30',
#   u'8/8/16 11:16',
#   u'8/8/16 10:30',
#   u'8/8/16 08:00',
#   u'8/8/16 06:20',
#   u'8/8/16 01:30',
#   u'8/8/16 00:00',
#   u'8/7/16 23:55',
#   u'8/7/16 23:24',
#   u'8/7/16 22:30',
#   u'8/7/16 21:35',
#   u'8/7/16 21:30',
#   u'8/7/16 21:30',
#   u'8/7/16 21:20',
#   u'8/7/16 19:45',
#   u'8/7/16 19:44',
#   u'8/7/16 04:09',
#   u'8/7/16 02:30',
#   u'8/7/16 01:12',
#   u'8/7/16 00:30',
#   u'8/6/16 23:30',
#   u'8/6/16 23:27',
#   u'8/6/16 23:00',
#   u'8/6/16 23:00',
#   u'8/6/16 22:45',
#   u'8/6/16 22:30',
#   u'8/6/16 22:00',
#   u'8/6/16 21:30',
#   u'8/6/16 21:30',
#   u'8/6/16 21:30',
#   u'8/6/16 21:30',
#   u'8/6/16 20:50',
#   u'8/6/16 20:45',
#   u'8/6/16 20:17',
#   u'8/6/16 20:10',
#   u'8/6/16 20:00',
#   u'8/6/16 19:45',
#   u'8/6/16 19:30',
#   u'8/6/16 12:15',
#   u'8/6/16 11:30',
#   u'8/6/16 09:43',
#   u'8/5/16 23:45',
#   u'8/5/16 22:40',
#   u'8/5/16 22:35',
#   u'8/5/16 21:46',
#   u'8/5/16 21:00',
#   u'8/5/16 21:00',
#   u'8/5/16 03:00',
#   u'8/5/16 02:39',
#   u'8/5/16 01:30',
#   u'8/5/16 00:00',
#   u'8/5/16 00:00',
#   u'8/4/16 22:50',
#   u'8/4/16 22:00',
#   u'8/4/16 20:30',
#   u'8/4/16 20:30',
#   u'8/4/16 20:20',
#   u'8/4/16 20:00',
#   u'8/4/16 19:53',
#   u'8/4/16 19:37',
#   u'8/4/16 19:30',
#   u'8/4/16 02:00',
#   u'8/3/16 23:45',
#   u'8/3/16 23:31',
#   u'8/3/16 23:00',
#   u'8/3/16 22:55',
#   u'8/3/16 22:00',
#   u'8/3/16 22:00',
#   u'8/3/16 22:00',
#   u'8/3/16 21:28',
#   u'8/3/16 21:22',
#   u'8/3/16 21:15',
#   u'8/3/16 21:00',
#   u'8/3/16 20:30',
#   u'8/3/16 14:45',
#   u'8/3/16 13:36',
#   u'8/3/16 04:10',
#   u'8/3/16 04:00',
#   u'8/3/16 02:30',
#   u'8/3/16 00:37',
#   u'8/3/16 00:20',
#   u'8/3/16',
#   u'8/2/16 23:15',
#   u'8/2/16 23:00',
#   u'8/2/16 23:00',
#   u'8/2/16 22:35',
#   u'8/2/16 22:15',
#   u'8/2/16 22:00',
#   u'8/2/16 22:00',
#   u'8/2/16 21:35',
#   u'8/2/16 19:25',
#   u'8/2/16 15:00',
#   u'8/2/16 11:15',
#   u'8/2/16 11:00',
#   u'8/2/16 05:15',
#   u'8/2/16 03:25',
#   u'8/2/16 02:30',
#   u'8/2/16 02:30',
#   u'8/2/16 01:30',
#   u'8/2/16 01:22',
#   u'8/2/16 01:15',
#   u'8/2/16 00:45',
#   u'8/1/16 23:04',
#   u'8/1/16 23:00',
#   u'8/1/16 22:45',
#   u'8/1/16 22:30',
#   u'8/1/16 22:30',
#   u'8/1/16 22:30',
#   u'8/1/16 22:00',
#   u'8/1/16 21:46',
#   u'8/1/16 21:45',
#   u'8/1/16 21:40',
#   u'8/1/16 21:30',
#   u'8/1/16 21:30',
#   u'8/1/16 21:27',
#   u'8/1/16 21:20',
#   u'8/1/16 21:00',
#   u'8/1/16 20:45',
#   u'8/1/16 20:45',
#   u'8/1/16 19:33',
#   u'8/1/16 19:27',
#   u'8/1/16 17:00',
#   u'8/1/16 16:00',
#   u'8/1/16 03:25',
#   u'8/1/16'],
#  'Shape': [u'Light',
#   u'Circle',
#   u'Light',
#   u'Light',
#   u'Triangle',
#   u'Sphere',
#   u'Light',
#   u'Unknown',
#   u'Chevron',
#   u'Light',
#   u'Egg',
#   u'Triangle',
#   u'Sphere',
#   u'Light',
#   u'Other',
#   u'Light',
#   u'Fireball',
#   u'Light',
#   u'Oval',
#   u'Sphere',
#   u'Sphere',
#   u'Changing',
#   u'Flash',
#   u'Cylinder',
#   u'Light',
#   u'Circle',
#   u'Cigar',
#   u'Disk',
#   u'Light',
#   u'Triangle',
#   u'Circle',
#   u'Triangle',
#   u'Other',
#   u'Rectangle',
#   u'Disk',
#   u'Light',
#   u'Triangle',
#   u'Circle',
#   u'Sphere',
#   u'Circle',
#   u'Sphere',
#   u'Light',
#   u'Circle',
#   u'Triangle',
#   u'Other',
#   u'Unknown',
#   u'Unknown',
#   u'Light',
#   u'Cigar',
#   u'Oval',
#   u'',
#   u'Formation',
#   u'',
#   u'Unknown',
#   u'Sphere',
#   u'Light',
#   u'Circle',
#   u'Oval',
#   u'Circle',
#   u'Egg',
#   u'Changing',
#   u'Other',
#   u'Triangle',
#   u'',
#   u'Other',
#   u'Cross',
#   u'Fireball',
#   u'Egg',
#   u'Formation',
#   u'Light',
#   u'Circle',
#   u'Light',
#   u'Light',
#   u'Flash',
#   u'Fireball',
#   u'Light',
#   u'Changing',
#   u'Light',
#   u'Light',
#   u'Fireball',
#   u'Sphere',
#   u'Unknown',
#   u'Disk',
#   u'Circle',
#   u'Triangle',
#   u'Rectangle',
#   u'Light',
#   u'Sphere',
#   u'Unknown',
#   u'Cigar',
#   u'',
#   u'Circle',
#   u'Light',
#   u'Oval',
#   u'Circle',
#   u'Fireball',
#   u'Light',
#   u'Diamond',
#   u'Sphere',
#   u'',
#   u'Unknown',
#   u'Unknown',
#   u'Triangle',
#   u'Fireball',
#   u'Formation',
#   u'Changing',
#   u'Flash',
#   u'Circle',
#   u'Other',
#   u'Light',
#   u'Oval',
#   u'',
#   u'Circle',
#   u'Rectangle',
#   u'Light',
#   u'Formation',
#   u'Other',
#   u'Cigar',
#   u'Light',
#   u'Other',
#   u'Circle',
#   u'Changing',
#   u'Fireball',
#   u'Cylinder',
#   u'Formation',
#   u'Light',
#   u'Light',
#   u'Light',
#   u'Light',
#   u'Triangle',
#   u'Triangle',
#   u'Triangle',
#   u'Sphere',
#   u'Light',
#   u'Light',
#   u'',
#   u'Other',
#   u'Disk',
#   u'Circle',
#   u'Rectangle',
#   u'Other',
#   u'Circle',
#   u'Light',
#   u'Sphere',
#   u'Light',
#   u'Unknown',
#   u'Cigar',
#   u'Disk',
#   u'Oval',
#   u'Fireball',
#   u'Unknown',
#   u'Light',
#   u'Other',
#   u'',
#   u'Fireball',
#   u'Other',
#   u'Light',
#   u'Light',
#   u'Triangle',
#   u'Circle',
#   u'Circle',
#   u'Light',
#   u'Disk',
#   u'Light',
#   u'',
#   u'Oval',
#   u'Unknown',
#   u'',
#   u'Sphere',
#   u'Sphere',
#   u'Unknown',
#   u'Light',
#   u'Oval',
#   u'Circle',
#   u'Sphere',
#   u'Fireball',
#   u'Light',
#   u'Light',
#   u'Triangle',
#   u'',
#   u'Oval',
#   u'Sphere',
#   u'Fireball',
#   u'Cigar',
#   u'Disk',
#   u'Oval',
#   u'Triangle',
#   u'Changing',
#   u'Unknown',
#   u'Light',
#   u'Triangle',
#   u'Changing',
#   u'Light',
#   u'Fireball',
#   u'Circle',
#   u'Disk',
#   u'Triangle',
#   u'Light',
#   u'Rectangle',
#   u'Circle',
#   u'Sphere',
#   u'Light',
#   u'Oval',
#   u'',
#   u'Fireball',
#   u'Fireball',
#   u'Light',
#   u'Fireball',
#   u'Circle',
#   u'Unknown',
#   u'Circle',
#   u'Triangle',
#   u'Flash',
#   u'Light',
#   u'Unknown',
#   u'Circle',
#   u'Fireball',
#   u'Circle',
#   u'Triangle',
#   u'Light',
#   u'Fireball',
#   u'Oval',
#   u'Triangle',
#   u'Oval',
#   u'Circle',
#   u'Circle',
#   u'Rectangle',
#   u'Fireball',
#   u'Formation',
#   u'Circle',
#   u'Light',
#   u'Light',
#   u'Oval',
#   u'Other',
#   u'Triangle',
#   u'Flash',
#   u'Triangle',
#   u'Circle',
#   u'Fireball',
#   u'Flash',
#   u'Light',
#   u'Sphere',
#   u'',
#   u'Circle',
#   u'Oval',
#   u'Light',
#   u'Cigar',
#   u'',
#   u'',
#   u'Flash',
#   u'Circle',
#   u'Circle',
#   u'Triangle',
#   u'Unknown',
#   u'Light',
#   u'Diamond',
#   u'Circle',
#   u'Formation',
#   u'',
#   u'Fireball',
#   u'Unknown',
#   u'Fireball',
#   u'Circle',
#   u'Circle',
#   u'Formation',
#   u'Light',
#   u'Light',
#   u'Fireball',
#   u'Light',
#   u'Triangle',
#   u'Circle',
#   u'Circle',
#   u'Other',
#   u'Circle',
#   u'Cigar',
#   u'Egg',
#   u'Sphere',
#   u'Disk',
#   u'Sphere',
#   u'Other',
#   u'',
#   u'Light',
#   u'Triangle',
#   u'Triangle',
#   u'Other',
#   u'Sphere',
#   u'Other',
#   u'Light',
#   u'Unknown',
#   u'Formation',
#   u'Light',
#   u'Light',
#   u'Other',
#   u'',
#   u'Light',
#   u'Other',
#   u'Disk',
#   u'Disk',
#   u'Light',
#   u'Sphere',
#   u'Chevron',
#   u'Circle',
#   u'Rectangle',
#   u'Rectangle',
#   u'',
#   u'Sphere',
#   u'Triangle',
#   u'Cylinder',
#   u'Light',
#   u'Light',
#   u'Light',
#   u'Disk',
#   u'Light',
#   u'Unknown',
#   u'Chevron',
#   u'',
#   u'Other',
#   u'Circle',
#   u'Oval',
#   u'Circle',
#   u'Disk',
#   u'Circle',
#   u'Light',
#   u'',
#   u'Light',
#   u'Egg',
#   u'Chevron',
#   u'Triangle',
#   u'Unknown',
#   u'Other',
#   u'Flash',
#   u'Chevron',
#   u'Formation',
#   u'Light',
#   u'Light',
#   u'Light',
#   u'Triangle',
#   u'Triangle',
#   u'Light',
#   u'Light',
#   u'Triangle',
#   u'Formation',
#   u'Triangle',
#   u'Chevron',
#   u'Changing',
#   u'Other',
#   u'Triangle',
#   u'Triangle',
#   u'Fireball',
#   u'Other',
#   u'Light',
#   u'Light',
#   u'Chevron',
#   u'Chevron',
#   u'Other',
#   u'Sphere',
#   u'Formation',
#   u'Cylinder',
#   u'Light',
#   u'Light',
#   u'Triangle',
#   u'Disk',
#   u'Light',
#   u'Oval',
#   u'Light',
#   u'Circle',
#   u'Circle',
#   u'Egg',
#   u'Other',
#   u'Formation',
#   u'Other',
#   u'Triangle',
#   u'Unknown',
#   u'Triangle',
#   u'Triangle',
#   u'Unknown',
#   u'Circle',
#   u'Flash',
#   u'Light',
#   u'Light',
#   u'Circle',
#   u'Light',
#   u'Triangle',
#   u'Circle',
#   u'Triangle',
#   u'Other',
#   u'Teardrop',
#   u'Sphere',
#   u'Oval',
#   u'Triangle',
#   u'Circle',
#   u'Fireball',
#   u'Circle',
#   u'Oval',
#   u'Unknown',
#   u'Other',
#   u'Triangle',
#   u'Circle',
#   u'Flash',
#   u'Triangle',
#   u'Light',
#   u'Triangle',
#   u'Disk',
#   u'',
#   u'',
#   u'Light',
#   u'Fireball',
#   u'Fireball',
#   u'Light',
#   u'Circle',
#   u'Fireball',
#   u'Triangle',
#   u'Triangle',
#   u'Unknown',
#   u'Light',
#   u'Cigar',
#   u'Circle',
#   u'Changing',
#   u'Circle',
#   u'Other',
#   u'Light',
#   u'Disk',
#   u'Triangle',
#   u'Circle',
#   u'Disk',
#   u'Light',
#   u'Unknown',
#   u'Fireball',
#   u'Cross',
#   u'Circle',
#   u'Light',
#   u'Sphere',
#   u'Light',
#   u'',
#   u'Circle',
#   u'Triangle',
#   u'',
#   u'Triangle',
#   u'Cigar',
#   u'Oval',
#   u'Sphere',
#   u'Triangle',
#   u'Circle',
#   u'Light',
#   u'Light',
#   u'Light',
#   u'Light',
#   u'',
#   u'Unknown',
#   u'Circle',
#   u'Fireball',
#   u'Circle',
#   u'Oval',
#   u'Cylinder',
#   u'Light',
#   u'Changing',
#   u'Oval',
#   u'Circle',
#   u'Triangle',
#   u'Formation',
#   u'Fireball',
#   u'Light',
#   u'Light',
#   u'Fireball',
#   u'Changing',
#   u'Triangle',
#   u'Light',
#   u'Unknown',
#   u'Unknown',
#   u'Light',
#   u'Oval',
#   u'Triangle',
#   u'Formation',
#   u'Egg',
#   u'Circle',
#   u'Light',
#   u'Light',
#   u'Cigar',
#   u'Changing',
#   u'Circle',
#   u'Flash',
#   u'Light',
#   u'Formation',
#   u'Cigar',
#   u'Triangle',
#   u'Circle',
#   u'Unknown',
#   u'Triangle',
#   u'Light',
#   u'Formation',
#   u'Light',
#   u'Light',
#   u'Circle',
#   u'Rectangle',
#   u'Oval',
#   u'Other',
#   u'Egg',
#   u'Fireball',
#   u'Circle',
#   u'Triangle',
#   u'',
#   u'Light',
#   u'Sphere',
#   u'Light',
#   u'Circle',
#   u'Oval',
#   u'Light',
#   u'Light',
#   u'Light',
#   u'Light',
#   u'Cone',
#   u'Light',
#   u'Other',
#   u'Light',
#   u'Triangle',
#   u'',
#   u'Light',
#   u'Triangle',
#   u'Circle',
#   u'Unknown',
#   u'',
#   u'Fireball',
#   u'Triangle',
#   u'Formation',
#   u'Circle',
#   u'Circle',
#   u'Light',
#   u'',
#   u'Light',
#   u'Unknown',
#   u'Light',
#   u'Formation',
#   u'Circle',
#   u'Circle',
#   u'Circle',
#   u'Changing',
#   u'Light',
#   u'Changing',
#   u'Disk',
#   u'Triangle',
#   u'Triangle',
#   u'',
#   u'Light',
#   u'Rectangle'],
#  'State': [u'IN',
#   u'CA',
#   u'WA',
#   u'WI',
#   u'NC',
#   u'CA',
#   u'NM',
#   u'OK',
#   u'MN',
#   u'TN',
#   u'MA',
#   u'OH',
#   u'AK',
#   u'TX',
#   u'CA',
#   u'AZ',
#   u'AZ',
#   u'MI',
#   u'CT',
#   u'CO',
#   u'PA',
#   u'NY',
#   u'UT',
#   u'NC',
#   u'CA',
#   u'NY',
#   u'IL',
#   u'SC',
#   u'CO',
#   u'SC',
#   u'NY',
#   u'UT',
#   u'VA',
#   u'MA',
#   u'MD',
#   u'GA',
#   u'WA',
#   u'VA',
#   u'FL',
#   u'NC',
#   u'OR',
#   u'MO',
#   u'NY',
#   u'OH',
#   u'WY',
#   u'TN',
#   u'NY',
#   u'CO',
#   u'ON',
#   u'ON',
#   u'NC',
#   u'AK',
#   u'NJ',
#   u'VA',
#   u'NH',
#   u'CA',
#   u'CA',
#   u'CA',
#   u'PA',
#   u'NJ',
#   u'NJ',
#   u'CA',
#   u'NM',
#   u'',
#   u'NY',
#   u'CT',
#   u'TN',
#   u'NC',
#   u'MI',
#   u'ON',
#   u'NY',
#   u'NY',
#   u'NJ',
#   u'KS',
#   u'SD',
#   u'CA',
#   u'WI',
#   u'CT',
#   u'FL',
#   u'NJ',
#   u'IN',
#   u'TN',
#   u'FL',
#   u'MD',
#   u'IL',
#   u'PA',
#   u'TX',
#   u'WI',
#   u'CA',
#   u'NC',
#   u'',
#   u'OR',
#   u'TX',
#   u'CA',
#   u'OR',
#   u'OH',
#   u'GA',
#   u'MA',
#   u'TN',
#   u'IL',
#   u'NC',
#   u'GA',
#   u'PA',
#   u'WA',
#   u'CO',
#   u'CO',
#   u'NY',
#   u'IL',
#   u'PA',
#   u'IL',
#   u'WA',
#   u'',
#   u'FL',
#   u'CA',
#   u'NY',
#   u'CA',
#   u'NY',
#   u'AL',
#   u'FL',
#   u'TX',
#   u'VT',
#   u'FL',
#   u'MI',
#   u'MA',
#   u'MD',
#   u'RI',
#   u'FL',
#   u'SC',
#   u'AZ',
#   u'MO',
#   u'VA',
#   u'OH',
#   u'ID',
#   u'MI',
#   u'PA',
#   u'',
#   u'AZ',
#   u'QC',
#   u'MA',
#   u'NH',
#   u'CA',
#   u'MO',
#   u'MI',
#   u'CO',
#   u'NJ',
#   u'AZ',
#   u'NJ',
#   u'CA',
#   u'NE',
#   u'CA',
#   u'CA',
#   u'TX',
#   u'WI',
#   u'',
#   u'MN',
#   u'YT',
#   u'OR',
#   u'OR',
#   u'CO',
#   u'MO',
#   u'WY',
#   u'FL',
#   u'NC',
#   u'KS',
#   u'',
#   u'OR',
#   u'AR',
#   u'',
#   u'NC',
#   u'IL',
#   u'MO',
#   u'UT',
#   u'MA',
#   u'CA',
#   u'VT',
#   u'PA',
#   u'GA',
#   u'NJ',
#   u'FL',
#   u'',
#   u'ME',
#   u'NJ',
#   u'IL',
#   u'CA',
#   u'CA',
#   u'IN',
#   u'ID',
#   u'NH',
#   u'WA',
#   u'NJ',
#   u'PA',
#   u'UT',
#   u'CA',
#   u'FL',
#   u'MD',
#   u'OH',
#   u'AR',
#   u'TN',
#   u'CA',
#   u'IN',
#   u'ME',
#   u'CA',
#   u'CA',
#   u'TN',
#   u'FL',
#   u'FL',
#   u'FL',
#   u'FL',
#   u'FL',
#   u'MI',
#   u'FL',
#   u'NJ',
#   u'UT',
#   u'GA',
#   u'PA',
#   u'OR',
#   u'AZ',
#   u'AZ',
#   u'GA',
#   u'CA',
#   u'CA',
#   u'NY',
#   u'CT',
#   u'OH',
#   u'TX',
#   u'LA',
#   u'CT',
#   u'FL',
#   u'NH',
#   u'MO',
#   u'CA',
#   u'AZ',
#   u'OR',
#   u'PA',
#   u'TX',
#   u'WA',
#   u'FL',
#   u'TN',
#   u'MI',
#   u'FL',
#   u'NC',
#   u'TX',
#   u'',
#   u'NM',
#   u'PA',
#   u'OR',
#   u'WA',
#   u'MI',
#   u'',
#   u'ID',
#   u'RI',
#   u'RI',
#   u'NJ',
#   u'NY',
#   u'OH',
#   u'TN',
#   u'NC',
#   u'CO',
#   u'SC',
#   u'CA',
#   u'CO',
#   u'CA',
#   u'AZ',
#   u'MN',
#   u'WV',
#   u'TN',
#   u'CA',
#   u'NY',
#   u'MA',
#   u'NE',
#   u'NJ',
#   u'CA',
#   u'WA',
#   u'NH',
#   u'ME',
#   u'WA',
#   u'MA',
#   u'WA',
#   u'WY',
#   u'OH',
#   u'',
#   u'WA',
#   u'SC',
#   u'GA',
#   u'OH',
#   u'ND',
#   u'CO',
#   u'FL',
#   u'OR',
#   u'IL',
#   u'WV',
#   u'WI',
#   u'WV',
#   u'',
#   u'WI',
#   u'FL',
#   u'KS',
#   u'NC',
#   u'MN',
#   u'NC',
#   u'CO',
#   u'PA',
#   u'CO',
#   u'OR',
#   u'',
#   u'MI',
#   u'VA',
#   u'CA',
#   u'OR',
#   u'MI',
#   u'WA',
#   u'MI',
#   u'NM',
#   u'NY',
#   u'CA',
#   u'',
#   u'CA',
#   u'MO',
#   u'NM',
#   u'FL',
#   u'NJ',
#   u'WA',
#   u'NM',
#   u'WV',
#   u'ON',
#   u'OH',
#   u'FL',
#   u'AZ',
#   u'NC',
#   u'CO',
#   u'OK',
#   u'WA',
#   u'HI',
#   u'AZ',
#   u'VT',
#   u'HI',
#   u'RI',
#   u'NH',
#   u'OK',
#   u'GA',
#   u'NH',
#   u'CO',
#   u'MI',
#   u'CA',
#   u'RI',
#   u'OR',
#   u'OH',
#   u'NH',
#   u'CA',
#   u'MD',
#   u'RI',
#   u'WA',
#   u'WA',
#   u'WA',
#   u'PA',
#   u'PA',
#   u'WA',
#   u'CO',
#   u'GA',
#   u'GA',
#   u'NY',
#   u'UT',
#   u'WI',
#   u'WA',
#   u'NY',
#   u'VT',
#   u'WA',
#   u'OH',
#   u'BC',
#   u'TN',
#   u'MT',
#   u'CA',
#   u'FL',
#   u'AK',
#   u'MO',
#   u'MI',
#   u'WI',
#   u'NC',
#   u'IL',
#   u'CA',
#   u'FL',
#   u'OK',
#   u'PA',
#   u'NC',
#   u'TN',
#   u'OH',
#   u'MA',
#   u'TN',
#   u'MD',
#   u'CO',
#   u'CA',
#   u'MA',
#   u'WA',
#   u'MN',
#   u'CA',
#   u'NC',
#   u'SC',
#   u'MI',
#   u'OR',
#   u'GA',
#   u'OR',
#   u'HI',
#   u'KS',
#   u'',
#   u'MS',
#   u'CA',
#   u'SC',
#   u'NC',
#   u'VA',
#   u'FL',
#   u'WY',
#   u'NJ',
#   u'DC',
#   u'CT',
#   u'NJ',
#   u'UT',
#   u'OH',
#   u'ID',
#   u'ID',
#   u'CA',
#   u'FL',
#   u'NM',
#   u'NV',
#   u'MD',
#   u'WA',
#   u'NC',
#   u'PA',
#   u'MI',
#   u'FL',
#   u'IN',
#   u'MN',
#   u'WI',
#   u'CA',
#   u'',
#   u'NY',
#   u'MD',
#   u'UT',
#   u'CA',
#   u'WA',
#   u'VA',
#   u'CT',
#   u'OH',
#   u'NY',
#   u'UT',
#   u'KY',
#   u'MN',
#   u'MI',
#   u'NY',
#   u'WV',
#   u'ID',
#   u'IL',
#   u'ID',
#   u'ID',
#   u'OH',
#   u'CT',
#   u'ID',
#   u'NC',
#   u'KS',
#   u'CA',
#   u'MN',
#   u'OK',
#   u'NH',
#   u'WA',
#   u'WV',
#   u'CT',
#   u'PA',
#   u'MI',
#   u'KS',
#   u'SC',
#   u'MI',
#   u'FL',
#   u'TX',
#   u'VA',
#   u'PA',
#   u'MA',
#   u'PA',
#   u'MA',
#   u'OH',
#   u'BC',
#   u'TN',
#   u'MD',
#   u'AL',
#   u'MA',
#   u'NY',
#   u'OH',
#   u'TN',
#   u'NM',
#   u'WI',
#   u'NJ',
#   u'NY',
#   u'SC',
#   u'LA',
#   u'WA',
#   u'PA',
#   u'CA',
#   u'NS',
#   u'NV',
#   u'MI',
#   u'IN',
#   u'PA',
#   u'',
#   u'MA',
#   u'NH',
#   u'TX',
#   u'NY',
#   u'NM',
#   u'NV',
#   u'IL',
#   u'IL',
#   u'AZ',
#   u'TX',
#   u'OR',
#   u'OH',
#   u'AL',
#   u'TX',
#   u'MO',
#   u'MO',
#   u'TX',
#   u'CA',
#   u'WA',
#   u'',
#   u'MO',
#   u'ME',
#   u'VA',
#   u'CA',
#   u'OH',
#   u'ON',
#   u'',
#   u'OR',
#   u'WA',
#   u'IN',
#   u'CO',
#   u'NS',
#   u'NE',
#   u'NE',
#   u'ME',
#   u'FL',
#   u'FL',
#   u'CA',
#   u'IA',
#   u'YT',
#   u'',
#   u'CO',
#   u'AR'],
#  'Summary': [u'Four unidentified moving flashing lights that hovered in place for several minutes. Terre Haute, Indiana',
#   u'Stationary yellow gold lights seen during extended long sighting',
#   u'Strange meandering craft pulls near 180 before streaking exit',
#   u'Fifteen minute sighting of unusual light formation north of Madison..',
#   u'We saw 3 triangle objects in the sky with Redish Orange Lights that hovered over the treeline and then disbursed into the sky.',
#   u'At 7:20pm I was in my backyard watering my garden in the city of pomona, ca. At 7:35pm i finish watering the garden and just stood arou',
#   u'Bright flashing spherical light appearing in NW sky at dusk before any other stars , and disappears w/in the hr. No sound.',
#   u'Was standing outside with my boyfriend as it was about to storm. I was taking pictures of the sky and we thought something seemed kind',
#   u'While out walking I saw slow moving bright objects that seemed to form shapes.  After 10 min. they changed direction and disappeared',
#   u'I stepped outside at about 1:38 and immediately noticed two stationary lights in the northeastern sky. I thought this very unusual, bec',
#   u'White/yellow glowing egg shaped object flying low south to north Holden, MA.',
#   u'6 to 7 bright white lights on triangular craft - North Columbus',
#   u'Red and blue color changing orb moving in all directions.',
#   u'4 white glows in the cloud cover circling like sparrows within a 1/4 mile.',
#   u'Once in a life time experience!!',
#   u'My girlfriend and I saw two lights hovering over the Tempe area.  We were looking south to southwest.',
#   u'At around 9:40 pm went outside and saw two bright orange fireballs side by side heading towards south mountain.  ((anonymous report))',
#   u'Star like object moving up, down, all over, silently about 12 seconds just at dark on cloudy night in S.W.sky.',
#   u'Saw a stationary pattern, not moving and not making any noise for a minute until it slowly dimmed away.',
#   u'Floating bright orb flashes then disappeared completely.',
#   u'Saw 3 red lights hovering in distance, about the height of typical aircraft. 3 red lights hovered in a triangular pattern, one by one,',
#   u'Golden bars shaped like a sphere with a glowing light inside of it, gliding towards us.',
#   u'Bright flash that lasted around 3 sec.  Then a smoke trail.  Was traveling it a E dir. Smoke trail continued. ((NUFORC Note:  Meteor?))',
#   u'UFO seen hovering South East 4 to 6 miles from Simmons Air field near Fort Bragg.  Roughly between 15000 to 20000 feet in altitude.',
#   u'Orange light travels across sky then disappears.',
#   u'I saw a dark silver circle shaped UFO for like 6 seconds flying very slow.',
#   u'Craft just disappeared.',
#   u'Saucer seen on I-26 and Ladson Rd.',
#   u'White dot over Boulder, CO.',
#   u'Multi-colored light seen to the west of Seabrook/Lobecco, SC.',
#   u'Looking up to the sky thought it was a shooting star; realized it was a very intense white light circle in shape.((anonymous report))',
#   u'Black triangle with white lights in corners.',
#   u'1 slowly moving aircraft gliding through tree line.  When in full sight it had lights rotating around in a circle one being red.',
#   u'Glowing orange rectangular object, slow moving and making no sound.',
#   u'We saw a ufo hovering for >1 hour; it never went in any dir. and was not a star, as we saw flashing red light. ((anonymous report))',
#   u'Shooting star stopped and hovered and was caught on video.',
#   u'3 or 4 lights in a perfect triangle arrangement, to the west of Arlington.',
#   u'2 Red lights flew over.',
#   u'5 orange-yellow lights near I-295 E of Buckman Bridge, moving slowly vertically and horizontally.',
#   u'Orange pulsating orb above beach.',
#   u'These spheres are white like electic and appear about 8:25 pm for weeks now they stay stationary for up to 4 to 5 minutes than descend',
#   u'Around 8:00 pm I noticed a low, but bright (slightly orange) light near the horizon, yet above the tree line. Somehow it got my attenti',
#   u'We saw 3 objects in the sky 2 moving horizontally and one falling at an angle vertically.',
#   u'Black triangle craft with 8 - 10 yellowish-white lights on side/red underbelly lights/quietly hums past window.',
#   u'Two silver/white objects. Generally stationary but appeared to ascend occasionally.',
#   u'2 unidentified objects seen early morning in Davidson County, TN.  ((NUFORC Not:  Possible star??  PD))',
#   u'Small flashing/blinking light in the sky moving in a circular/triangular form with red, white, and blue like lights.',
#   u'3 of us seen a white light heading Twards the mountain bobbing back and forth almost like it was confuse before it just disappeared.',
#   u'Imagine for a moment, as if the pattern of a tiger\u2019s stripes was energetically oscillating at an extremely fast rate.',
#   u"It appeared as a quickly pulsating, oscillation with long, oval arch to each side, moving at the speed of a meteorite, but wasn't.",
#   u'2 nights consecutive I witnessed from my back deck facing West toward Ft. Bragg an illuminous orange orb. ((NUFORC Note:  Venus??  PD))',
#   u'3 lights; blue green; straight line; moved vertically.',
#   u'Bright white light went back n forth in sky with 2 fighter jets flying next to each other following after it!',
#   u'Red, blue, and white silent hovering object over treeline.',
#   u'4  yellow/orange spheres moving slowly in sky.  Three in a row in front. The other was a distance behind the middle one. No Sound.',
#   u'White light seen hovering in sky.',
#   u'UFO over Petaluma on August 28, 2016, @ approximately 7:30 pm..',
#   u'Initial object was very bright in the clear eastern sky with no other stars or commercial objects visible - bright white oval, football',
#   u'Metallic circle craft seen in sky.',
#   u'Middlesex NJ 8-10mins 2 3D objects turned into one white circle with a hole in the middle',
#   u'Middlesex NJ 8-10mins 2 3D objects turned into one white circle with a hole in the middle',
#   u'From one side of the sky to the other Out came a Gigantic almond shape blurry cloud at Mach speed right over me in city of Sylmar',
#   u'Dark grey, nodular, triangular craft passed overhead above tree line and made absolutely no noise.',
#   u'Bright red light craft disappeared into thin air.',
#   u'Strobe UFO.  ((anonymous report))',
#   u'Cross like object glowing the went in a split second over the sky.',
#   u'5 bright red orbs traveling west then slowed stopped and turned to the south and faded out.',
#   u'6 glowing orbs floating silently just above the houses.',
#   u'((HOAX??))  Moving in a single line,moving in one direction.  ((anonymous report))',
#   u'Bright light appears on highway with other drivers witnessing.',
#   u'Three Flaming Balls Over Spencerport, NY',
#   u'Group of 5 solid amber/orange lights, traveling in an open formation from northwest to southeast.  ((anonymous report))',
#   u'Lights in the sky at Jimmy Buffett Concert.',
#   u'Rapid moving flash of light while taking movie of clouds.',
#   u'Brilliant fireball traveled from east to west.  ((anonymous report))',
#   u'Six red lights in a row, traveling SE near Hollister.  ((anonymous report))((Report re-posted.))',
#   u'South on I-94 Saturday , 08.27.16 at 8:45 pm irregular round shape initially and then unraveling before disappearing.',
#   u'We saw a very fast moving bright light moving to the east.  After approximately 15 seconds...it just faded out.  We had an aircraft vis',
#   u'We currently are experiencing strange appearances in the sky : one blue light and another red light always almost close to each other a',
#   u'Fast fireball across sky.',
#   u'Large red sphere with protrusions from top and bottom traveling silently from East to West silently and the size of a grapefruit.',
#   u'Seen same object twice since 07/22/16',
#   u'Hovering in sky with no sound.  ((NUFORC Note:  Twinkling star?  PD))',
#   u'((HOAX??))  My gf observed a very large bright light hovering in the sky much bigger than a star.  ((anonymous report))',
#   u'It was triangular in shape it looked like several spheres making connected making up the triangle.  It had a weird glow to it, it was f',
#   u'Three black rectangular objects, traveling in a line at low altitude with no sound or apparent means of propulsion.',
#   u'I live on the northside and at 8pm I notice that dark clouds and lightning began forming on the westside of town-my next destination. W',
#   u'Intensely white round object moving over 4-lane highway in daylight and hit my car.',
#   u'Sky suddenly dimmed during a lunchtime walk.',
#   u'White, pill shaped, silent, wingless aircraft  glided from north to south across the horizon in full daylight.',
#   u'Bluish green object moving up and down over a lake.',
#   u'Large yellow orb crossed the sky twice heading east.',
#   u'Extremely bright light grew faint and stopped.',
#   u'Two fiery deep orange oval-ish shapes erratically flying from north heading southbound against local flight patterns, then disappearing',
#   u'Red round light bouncing around the sky quickly',
#   u'Golden glowing, flame like orb in night sky.',
#   u'Lights in the sky in Kennesaw.',
#   u'Two groups of orange diamond shaped lights moving very slowly (7 total diamonds) independently of each other and gone within 3 mins.',
#   u'At around 4:15 p.m.,as I was waiting to pick my child up from basketball practice, I noticed a small silver circular object in the sky.',
#   u'',
#   u'At first appearance we thought it was a star.Noticed it was flashing, noticed color changing, Red white green blue, has stayed in s',
#   u'unexplained object that disappeared into the nite sky.',
#   u'08/24/2016 large, silent, triangular object flew over farm.',
#   u"Third time I've seen this.  This time strange because they were red at first than turned white toward Ft. Lewis.",
#   u'In Pinon Flats in Great Sand Dunes.  My friend and I were taking photos of the night sky.  ((NUFORC Note:  Insect in flight?  PD))',
#   u'Shape changing square/diamond UFO with circle lights that changed color.  Flying very low.',
#   u'Streak of light over Whitehall, NY, pauses then vanishes is a flash of light lasted just seconds.',
#   u'Ufo maybe?',
#   u'I just witnessed 2 fighter jets escorting what looked to be a huge dark thing.  At first I thought it was an airplane.',
#   u'Two white lights seen by two separate people 30 minutes apart in same location, central IL.',
#   u'At first I thought it was just someone playing with a drone because it was moving around all over the place, but it kept moving.',
#   u"Hi, i'm Brazilian and i'm trying to type in english, so...I have one veridc video I were walking to my home, and, one light, like a",
#   u"Driving E.  In the SE direction, I notice a bright white light that isn't moving.",
#   u"3 rectangular UFO's, white, black, and grey.",
#   u'Bright stationary lights in the sky that looked like stars in bright day light.',
#   u'Driving towards San Jose area this morning and noticed small bright lit craft hovering in distance; area was hilly.',
#   u'Partial CLOSE-UP picture of UFO over Oneida Lake, NY. 8/24/16 @ 6:31am',
#   u'I was leaving work on I-65 S, @ around government blv exit and saw this in the air for a few minutes.',
#   u'Flashing circular objects moving.',
#   u'Huge cloud of smoke, with a bright flashing light changing from pink to purple at each flash.  Appeared to be from a very large fire.',
#   u'Bright flash of circler light over Green Mt..',
#   u'10:54 PM EST Seminole, FL.  Leaving out home next to Seminole High School, we noticed an odd light arrangement in the sky.',
#   u'2 bright orange/red balls moving SSE to NNW (one after the other) across sky in approximately 10 seconds.',
#   u'Fast straight down.  Lights underneath.  ((anonymous report))',
#   u'I saw 5 lights, in the shape of a "V," flying across the sky in Ocean City, MD.',
#   u'For ~2 mins., a low lying bright amber covered light hovered in the sky and disappeared without moving and in the area of a/c.',
#   u'On the night of Aug 23 at around 9 to 9:30pm I observed a group of about 20 orange/red Lights traveling from west to east in the sky. T',
#   u'Star-like object disappears into clouds.',
#   u'Lights in the sky.',
#   u'I-70/MM 90, I saw two low-flying triangular crafts.  They were massive and appeared to be flat. ((NUFORC Note:  B2 bombers.  PD))',
#   u"Triangular objects moving East within fast moving clouds at Comer's Rock campground, Grayson, VA",
#   u"((HOAX??))  the of us had seen it on the right side above a neighbor's house.  ((anonymous report))",
#   u'Large green glowing spherical light traveling north at high rate of speed.  No tail, no sound.',
#   u'Two red glowing lights, moving slowly southeastward, looking from central Ann Arbor.',
#   u'Flash of light falls from sky and disappears when it hits the ground.  ((anonymous report))',
#   u'Black silent hight speed triangle.',
#   u'I saw two bright orange lights in the night that slowly glowed on , then slowly glowed off.',
#   u'Disk-shaped object with 3 pairs of lights appears in photo taken of planets in the night sky.',
#   u'Bright circle light being, followed by two helicopters.  ((anonymous report)).',
#   u'Rectangular object with square lights on the same level, but randomly spaced on the lower surface.',
#   u'Flat, agile.',
#   u'Looked up and saw a yellow/orange stationary light that was brighter than a shooting star slowly get brighter over about two seconds.',
#   u'Pulsing bright light near sundown.  ((anonymous report))',
#   u'One large orange ball crossed the sky above the horizon at apporximately 8:15 on 8-22-16 in Montrose, CO.',
#   u'Glowing object slowly moved across the sky near 8 PM.',
#   u'Lights and entities in Northern Arizona.',
#   u"Driving on Kings Highway, my husband, daughter and I, saw something in the sky.   It wasn't a plane, and there were 3 of them.",
#   u"Shape of a saucer.  Moved quickly.  Was only 1; grey.  I'm a 29 yr old college-educated female. ((anonymous report))",
#   u'Sphere not moving than vanished in seconds.',
#   u'Orange light in sky that makes explosion sounds.',
#   u'Slow moving bright light shoots pyrotechnic toward ground over rural Perris, Gavilan Hills.',
#   u'Bright white flashing and moving light that followed along side 2 passengers in a car over 20 miles up above the tree line at night',
#   u"7 bright stared lights in a single file fashion. White. Couldn't see if they were connected.",
#   u'Light stayed for 10 or 15 minutes then slowly moves and fades.',
#   u'Seen a glowing object, kind of at first looked triangular then turned into more of a fire ball look.  Glowing.',
#   u'((HOAX??))  Cool scary and weird.',
#   u'Camping outside when a bright light in the sky flashed, moved to the right, then faded out.',
#   u'Bright white light in night sky flashed, moved to the right, then faded out.',
#   u'4 triangular shaped craft in formation, no lights, no noise.',
#   u'My mom called me out from where I was inside the house, telling me to come quick. She said that my dad had seen something.',
#   u'Was driving mid morning and saw 6 spheres flying together and moving around each other.  They were shiny and silver looking.',
#   u'Light in sky that looked like a star but just started to move left right all around it was not a star stars dont move',
#   u'Looked like a flying saucer.',
#   u'Five people watched three different colored lights move around the sky North of Wellington, Kansas.',
#   u'20 minutes',
#   u'Cant explain two red fireballs over Portland.',
#   u'Large white spiraling light traveling at incredible speed.',
#   u'Lights moving in groups of 3, forming shapes and blinking.',
#   u'1 orb fading in and out, in the sky.',
#   u'My wife and I were in Chicago and we witnessed 8 orange/red/bright spheres slowly going overhead. I am ex Navy and stationed on the USS',
#   u'Extremely bright white and red flashing lights outside, lighting up our bedroom.',
#   u'35-50 white star-like lights, moving a cross sky, toward NSA building.',
#   u'Orange oval craft with no sound.',
#   u'My wife and I both saw three orange lights in the sky, moving in different directions, and making no sound.',
#   u'Two craft pass slowly at low elevation, a few minutes apart.',
#   u'Four fireball orbs visible over Pymatuning Lake.',
#   u'Orange ball of light in the sky.  ((anonymous report))',
# ...
#   u'Midnight adventure car ride to the top of a mountain greeted by something beyond this earth?',
#   u'I seen a triangle light changing gree to blue to white.  See it strait to the N toward st louis.  Video.',
#   u'Large UFO mistaken for airplane bright lights shines down went one direction and instantly went opposite direction w/o turning around.',
#   u'Round Red Orb formed into two orbs and hovered over me a minute I walked back in the house came out and they were gone but then they se',
#   u'Two, separate bright red flashing simultaneously balls of light flying in formation very low in sky with no sound. Moving N-S, slowly.',
#   u'Light in Sky Swirled (August 10th 2016).  ((anonymous report))',
#   u'A mixture of excitement and sheer curiosity is the intent i am coming from let me say that first. my stance or perspective about my exp',
#   u'Driving down the highway there was a big bright circular light, it would dim and get really bright again. Then it would break off into',
#   u'Colorful lights in the night sky.',
#   u'Layers of illuminating green light in the shape of a triangle moving very fast toward the ground.  ((Meteor??))',
#   u'Circular Blue object appearing in the sky',
#   u'Flashing stationary triangles which are not stars',
#   u'Very short siting of two bright lights, climbing straight up and disappearing.',
#   u'Looking out my back porch window after letting my dog outside, I noticed 2 lights in the sky resembling a tear drop shape.',
#   u'Dark Red Orb Slowly Moving Across Skyline.',
#   u'Very bright object shining like a star but in an oval shape, and moving extremely fast, without a smoke trail.',
#   u'Noticed a triangle object flying from Broomfield area to Boulder.  ((anonymous report))',
#   u'Invisible looking with fading out lights around rims of circle.',
#   u'I was getting of exit 19 off of 24 south heading into Avon when I saw a green fireball shooting down only a few hundred feet from the g',
#   u'Bright flashing light too fast to be anything but a ufo following me in my truck.',
#   u'Dim shape in night sky making incredible movements.',
#   u'I started investigating on my own starting the end of month July up to present day. Unless objects just disappeared for whatever reason',
#   u'Saw what sounded like a helicopter, but looked so wrong once, and then two more times during a meteor shower.',
#   u'((HOAX??))  Odd blinking lights, 3 in a shape of a triangle, and one dull but bright orange sphere shaped light.',
#   u"Orange orb UFO's transform and possibly land on Detroit's westside",
#   u'Orbiting object flares, separate flash appears, then object disappears.',
#   u'Triangular shaped cluster resembling Stars',
#   u'Bright white orb.',
#   u'Triangle aircraft with a bright red marker light blinking.',
#   u'Looking into the southeastern sky a cylinder shaped object became extremely bright and then became dim. About 5 seconds later one light',
#   u'Silver ball in the sky moving roughly the speed of a plane.  ((NUFORC Note:  International Space Station??  PD))  ((anonymous report))',
#   u'',
#   u'Driving to work on I-580, saw a glowing craft moving along the coast of California. It was a bright greenish color, moved extreamly fas',
#   u'Red flare-like object appeared 15-30 degrees above horizon. The object proceeded towards the horizon line at an extremely high speed. A',
#   u'Yellow Orangish fireball observed over Emerald Isle, NC.  ((anonymous report))',
#   u'Multi-colored light moving sporadically across the sky.  ((NUFORC Note:  ISS was in N sky at 22:55 hrs..  PD))',
#   u'((NUFORC Note:  Witness does not provide any information about the sighting.  PD))',
#   u'Glowing ball of light moved slowly across sky 8/9/16 in UFO in Sheridan, WY.',
#   u'SAW A LARGE TRIANGULAR CRAFT AND OTHER SMALLER ROUND CRAFT IN THE SKY.  LIKELY NOT OF THIS EARTH.',
#   u'There are 3 lights in the DC sky that are stationary and forming a triangle.',
#   u'Connecticut sighting - blunt triangle shaped craft cruises over dense suburban neighborhood at night.',
#   u'They just fly over head and disappear to the north parallel to the ocean. They look to be very high up. ((NUFORC Note:  Aircraft.  PD))',
#   u'Cigar-shaped object hovering over mountains East of Sandy, UT',
#   u'When looked at with the naked eye it looked like a circle, but very far away. Almost like a star during the day lit sky. Then when we u',
#   u'Odd ship that changed shapes, then back to original round shape, possible lights on it.',
#   u'Rotating circular object with antennae.',
#   u'Bright floating tinfoil looking object.',
#   u'At least 20 different colored shining objects in the sky that are moving.',
#   u'Bright white disk shaped object travelled along side of our vehicle for about 30 minutes.',
#   u'Object observed from flight from Las Vegas to Vancouver.  ((NUFORC Note:  Nice photo of approaching B2 bomber.  PD))',
#   u'UFO during sunrise.  ((NUFORC Note:  Lens flares, caused by pointing a camera toward the Sun.  PD))',
#   u'White saucer shaped craft, with black tinted windows, and with no noise.',
#   u'Bright green neon laser light.',
#   u'Craft with orange lights moved north of me.',
#   u'A ball of light, followed by fire, went through the sky and stopped to blend in as a star.',
#   u'((NUFORC Note:  Witness provides no information.  PD)) ((anonymous report))',
#   u'Watched an orange circular globe travel from east to west.  It disappeared after it enters a high cloud.',
#   u'Looking North East. We see what we first thought was a plane. But it looked out of place. Only bright forward light. No blinking, red,',
#   u'Flying bright orbs that flew around in a tight area like firefilies',
#   u'2 orange lights ascended into the sky until no longer visible.  ((anonymous report))',
#   u"((HOAX??)) Green-colored flash, which was moving through sky w/o any noise.  I'm sure it wasn't crackers. ((anonymous report))",
#   u'Bright orange circle broad daylight.  ((anonymous report))',
#   u'Two triangle UFOs were spotted, one followed a commercial plane for a few seconds.',
#   u'My girlfriend and I went up to the mountains to lay under the stars and look for stars, satellites, and meteors. We saw plenty of them.',
#   u'Triangle shape, with 3 lights.',
#   u'Straight Line of White Circular Lights Traveling W to E',
#   u'Craft over the city with two bright lights on the middle.  It just sat there with out moving.  It was as big as a blimp.',
#   u'Orange orb flys over Bridgeport, CT.',
#   u'((HOAX??))  Boy scout road UFO sighting.',
#   u'Appeared from nowhere in the east sky moving slowly south, then just disappeared.',
#   u"They looked like a hundreds of satellites drifting through the sky. Glittery blinking lights heading Northwest. Very strange. I can't s",
#   u'3 red lights moving in the sky over the trees',
#   u'Fast, bright moving object in Northern Minnesota',
#   u'Looked like stars at first. Then stars where moving slow and low in the sky. There was no sound. We saw two lights joined. It was nothi',
#   u'Orange balls or boat shapes, silent slow, over 15.',
#   u'Very Bright Lights over Mt. Lookout, WV.',
#   u'Right in the middle Vega and Arcturus was a bright circular light that looked like a planet but disappeared after only 20 minutes.',
#   u'About a dozen fireballs passing overhead in single file but irregularly spaced.  ((anonymous report))',
#   u'Shiny daytime ufo over nampa idaho 08/06/2016',
#   u'Bright orb viewed in twilight and night sky over Meridian/Nampa, Idaho.  ((anonymous report))((NUFORC Note:  Pilot report.  PD))',
#   u'White cylinder.',
#   u'I saw a yellow orange light in the distance  Thaught it might have been the moon but as we got to Ansonia it was HUGE',
#   u'White stationary object remaining for >20 min and counting very very high in atmosphere.  Changing shape from oval to angular.',
#   u'Saw UFO between a double-rainbow outside a restaurant.   ((NUFORC Note:  Possible lens flare, we suspect.  PD))',
#   u'White roundish object moving in sky.',
#   u'Huge black triangular UFO seen over Los Angeles, CA, at 11:30 AM, August 06, 2016.',
#   u'Three bright lights in a perfect triangle position.  Above Dayton Bluff area & east side of the St paul,MN',
#   u'Basketball sized dull reddish orange Orb flew decidedly around tree tops and past my 3rd story apartment balcony.',
#   u'Single light with a slight halo moving across the sky like a satellite; continuously changed its speed.  ((NUFORC Note:  ISS.  PD))',
#   u'Moving small white star (International space station?)  ((anonymous report)) ((NUFORC Note:  ISS @ 22:25 hrs..  PD))',
#   u'Bright red object seen in sky.  ((anonymous report))',
#   u'Green light pulsating vertically for about 15 minutes behind clouds,  when clouds passed green light went into a ball and craft flew of',
#   u'Three triangular shaped crafts with bright orange lights',
#   u'3 crafts spotted hovering for hours over Lenawee County.  Red & white flashing lights approached quickly, then slowly rise into sky.',
#   u'When going through the pictures I had taken, I noticed a few pictures with an object in them.',
#   u'2 lights combined to become one and dissapeared.  ((anonymous report))',
#   u' It looked like a star but would change to a lite blue, to red, to star white. ((NUFORC Note:  Star or planet?  PD))',
#   u'colored oval shaped light in the sky.',
#   u'Triangular blue aircraft seen leaving/darting from commercial airplane at night.',
#   u'Lights flashed for about 4 seconds then went away. About 2 minutes later it happened again but in a different pattern.',
#   u'Bright white object seen before sundown, larger than a star or planet, but disappeared by nightfall.',
#   u'Two orange orbs being chased by a military craft.',
#   u"Very large, non-moving object northern sky at 340 deg.. It was like the largest non-twinkling star I've ever seen but it was too early.",
#   u'BRIGHT LIGHT, LUDLOW, MA, EAST STREET.',
#   u'Metallic Pill Shaped UFO flys overhead at park near Wright Patterson Air Force Base.',
#   u'Flying object outside of aircraft.',
#   u'Green ball bouncing around in front of storm.',
#   u'((HOAX??)) In Rosedale MD.at 2:00 a.m looking up in the sky, I noticed a circle shaped object.  ((anonymous report))',
#   u'3 people outside there home witnessed 2 different types of unknown number of objects over Toney, AL.',
#   u'Five stationary bright red lights in northeast MA/southeast NH fading in then out.',
#   u'Low craft hovering slowly over Hudson River.',
#   u'I observed a triangle, lighted object hovering.',
#   u'Late on 08/03/2016, I was walking to my car and as I shut the car door I noticed a bright orange/ red ball three to be exact.the',
#   u'Matrix of bright green lights with loud whirring noise moving slowly above Boy Scouts at Philmont Scout Ranch Elk Horn camp.',
#   u'Three bright white lights, and one blinking red light in the shape of a triangle.',
#   u'Red light hovering in same place for several minutes.',
#   u"At 9:22 pm there was a straight line of 14 lights that I picked up on a deer camera. It appears to be positioned around 20-25'above.",
#   u'Bright White Light appeared in night sky, then got brighter, with a blue hue and appeared as if passing thru a light cloud layer.',
#   u'I felt very nauseated and anxious after the sighting with my witness.  ((anonymous report))',
#   u'Dim moving light in the sky turned extremely bright and stopped for 20 seconds, before going dim again and heading in a diff. dir..',
#   u'The object was a large dark square or rectangle that had a smaller object slightly above and ahead that was reflective silver.',
#   u'Strange, white, glowing, moving lights where seen by at least 5 people during the day.',
#   u'Three white lights on top an one light on bottom a cluster of lights together not moving or flashing.',
#   u'These were not US aircraft.',
#   u'orange ball of fire moving in all directions and complete stops, and restarts straits of mackinaw',
#   u'Flashing green lights; they are shifting and moving irradically.  No flight pattern is discernable. ((anonymous report))',
#   u'Red white and yellow lights, moving erratically.  ((anonymous report))',
#   u'',
#   u'I witnessed a star-like light slowly moving across the night sky.  Was traveling S to N.',
#   u'Full moon-like orbs traveling high in the night sky.  ((anonymous report))',
#   u'2 UFOS OVER EAST AUSTIN.',
#   u'2 lighted ships over Centereach NY. One was lit with blue lights the other was lit in red lights',
#   u'Something strange.',
#   u'Flashing/pulsing green light in northwest vegas sky.',
#   u'This looked like 2 lights that were about 3 inches apart if you were measuring from about 12 inches in front of your face.  They were o',
#   u'Two lights, one following the other until both disappeared, then one light at equal speed going the opposite direction.',
#   u'This was not a plane or helecopter.',
#   u'my 6 yrs daughter saw a cone shape object with green and yellow lights flying above in daytime',
#   u'Sitting on my porch with my significant other and saw a light appear from the sky and come down stay for a second and then go back up t',
#   u'I looked into the sky tonight, because I saw a flashing light and what I saw amazed me. I saw what looked like a jetpack of some sort,',
#   u'Odd, intermittent and slow strobing light.  Strobing was random and bright white.',
#   u"I noticed a couple of lights out in the distance I couldn't tell what it is.  ((anonymous report))",
#   u'Strange lights hovering near the gateway arch.  Fox2now.com has the video footage.',
#   u'Unusual light over the STL Arch; eyewitness reports the light to be about 100 ft. above the top of the structure. ((anonymous report))',
#   u'Witnessed three white lights in triangle formation move in the sky unlike any other "flying object."',
#   u'2 silver sphere ufos.',
#   u'Bright flash in the sky.',
#   u'Myself and my partner where out smoking when we both seen a light (the same size as a star but brighter) travelling at great speed (abo',
#   u'Big bright red-orange object flying horizontally at about 5000ft-10000ft rotating slightly as it moved Northeast.',
#   u"I'm actually not sure of the actually date but I do know this particular event happen in August. My boyfriend and I go out looking as o",
#   u'Two slow moving strobing lights moving steady in a western direction.',
#   u'UFOs seen over Chico, CA.  ((anonymous report))',
#   u'Hovering disc with two red lights on it.',
#   u'LOTS OF ACTIVITY OVER LAKE ERIE DURING FIREWORKS ON CIVIC HOLIDAY.',
#   u'Four floating lights, hovered about 500m above ground then disappeared.  ((anonymous report))',
#   u'We were walking past an athletic field when we looked over and noticed 3 lights in the sky that we had never seen before.Two of us',
#   u'I noticed a light way up in the sky, and quickly realized a second light following.  ((anonymous report))',
#   u"Orange orb gliding above tree line from east to west.  It blinked it's light off then on 3-4 times and dropped a faint silver object.",
#   u'5 colored lights moving in sky east to west.',
#   u'Strange balls of light seen in sky over Cape Breton Island, Nova Scotia, Canada.',
#   u'Black ufo spotted on a late night drive.',
#   u"It was late at night the object was a distance away but we're able to see a red light and possibly a green light as well going down.",
#   u'Saw a yellowish craft that turned into a disc over the beach in night sky in Old Orchard Beach, ME.',
#   u'Red lights, three, moving from east to west, the stright up.',
#   u'Three bright reds lights crossing the sky, and then straight up and out of sight.',
#   u'Two saucers and a lighting bolt',
#   u'1000 yards alt, triangular (large) floated over home traveling west to due East-complete w/ lights.  Was silent.',
#   u'White triangle with speed of a modern jet. Sky cracked open.  ((anonymous report))',
#   u'Long, cylindrical plane-like object appeared stationary in the sky for several hours.',
#   u'Sky cracked open.',
#   u'It looked like a brown boxcar way up into the sky.  In approximately three seconds it disappeared behind a cloud.']}

# %%
import pandas as pd

# %%
pd.DataFrame(ufo_sightings) # MAGIC
# Out:
#                                             City           Date      Shape  \
# 0                                    Terre Haute  8/31/16 23:40      Light
# 1                                   Corte Madera  8/31/16 22:00     Circle
# 2                                           Malo  8/31/16 22:00      Light
# 3                                      Arlington  8/31/16 21:00      Light
# 4                                        Concord  8/31/16 21:00   Triangle
# 5                                         Pomona  8/31/16 19:46     Sphere
# 6                                         Grants  8/31/16 19:38      Light
# 7                                  Oklahoma city  8/31/16 16:45    Unknown
# 8                                      Shoreview  8/31/16 12:00    Chevron
# 9                                        Memphis  8/31/16 01:38      Light
# 10                                        Holden  8/30/16 23:57        Egg
# 11                                      Columbus  8/30/16 23:56   Triangle
# 12                                     Anchorage  8/30/16 23:08     Sphere
# 13                                        Spring  8/30/16 22:30      Light
# 14                                       Menifee  8/30/16 21:50      Other
# 15                                         Tempe  8/30/16 21:45      Light
# 16                                         Tempe  8/30/16 21:40   Fireball
# 17                                       Zeeland  8/30/16 21:00      Light
# 18                                     Ellington  8/30/16 20:45       Oval
# 19                                       Greeley  8/30/16 20:30     Sphere
# 20                                    Pittsburgh  8/30/16 20:00     Sphere
# 21                         New York City (Bronx)  8/30/16 20:00   Changing
# 22                                         Hyrum  8/30/16 19:59      Flash
# 23                                  Fayetteville  8/30/16 17:40   Cylinder
# 24                                    Dana Point  8/30/16 16:00      Light
# 25                                         Utica  8/30/16 11:30     Circle
# 26                                  West Chicago  8/30/16 11:00      Cigar
# 27                                        Ladson  8/30/16 09:50       Disk
# 28                                       Boulder  8/30/16 07:40      Light
# 29                                      Seabrook  8/30/16 03:00   Triangle
# ..                                           ...            ...        ...
# 514                                       Austin   8/2/16 03:25   Triangle
# 515                                    St. Louis   8/2/16 02:30
# 516                                    St. Louis   8/2/16 02:30      Light
# 517                                      Houston   8/2/16 01:30   Triangle
# 518                                    Pittsburg   8/2/16 01:22     Circle
# 519                                     Puyallup   8/2/16 01:15    Unknown
# 520  Alexandria (W. Dunbartonshire)(UK/Scotland)   8/2/16 00:45
# 521                                   Florissant   8/1/16 23:04   Fireball
# 522                                      Augusta   8/1/16 23:00   Triangle
# 523                                      Hiltons   8/1/16 22:45  Formation
# 524                                        Chico   8/1/16 22:30     Circle
# 525                                    Baltimore   8/1/16 22:30     Circle
# 526             Port Colbourne (Ontario)(Canada)   8/1/16 22:30      Light
# 527                         Zurich (Switzerland)   8/1/16 22:00
# 528                                    Milwaukie   8/1/16 21:46      Light
# 529                                    Shoreline   8/1/16 21:45    Unknown
# 530                                  Shelbyville   8/1/16 21:40      Light
# 531                             Colorado Springs   8/1/16 21:30  Formation
# 532                       New Waterford (Canada)   8/1/16 21:30     Circle
# 533                                        Omaha   8/1/16 21:27     Circle
# 534                                     La Vista   8/1/16 21:20     Circle
# 535                            Old Orchard Beach   8/1/16 21:00   Changing
# 536                                 Jacksonville   8/1/16 20:45      Light
# 537                                 Jacksonville   8/1/16 20:45   Changing
# 538                                       Blythe   8/1/16 19:33       Disk
# 539                                      Dubuque   8/1/16 19:27   Triangle
# 540                                Mayo (Canada)   8/1/16 17:00   Triangle
# 541                              Menorca (Spain)   8/1/16 16:00
# 542                                     Lakewood   8/1/16 03:25      Light
# 543                                Mountain Home         8/1/16  Rectangle
#
#     State                                            Summary
# 0      IN  Four unidentified moving flashing lights that ...
# 1      CA  Stationary yellow gold lights seen during exte...
# 2      WA  Strange meandering craft pulls near 180 before...
# 3      WI  Fifteen minute sighting of unusual light forma...
# 4      NC  We saw 3 triangle objects in the sky with Redi...
# 5      CA  At 7:20pm I was in my backyard watering my gar...
# 6      NM  Bright flashing spherical light appearing in N...
# 7      OK  Was standing outside with my boyfriend as it w...
# 8      MN  While out walking I saw slow moving bright obj...
# 9      TN  I stepped outside at about 1:38 and immediatel...
# 10     MA  White/yellow glowing egg shaped object flying ...
# 11     OH  6 to 7 bright white lights on triangular craft...
# 12     AK  Red and blue color changing orb moving in all ...
# 13     TX  4 white glows in the cloud cover circling like...
# 14     CA                   Once in a life time experience!!
# 15     AZ  My girlfriend and I saw two lights hovering ov...
# 16     AZ  At around 9:40 pm went outside and saw two bri...
# 17     MI  Star like object moving up, down, all over, si...
# 18     CT  Saw a stationary pattern, not moving and not m...
# 19     CO  Floating bright orb flashes then disappeared c...
# 20     PA  Saw 3 red lights hovering in distance, about t...
# 21     NY  Golden bars shaped like a sphere with a glowin...
# 22     UT  Bright flash that lasted around 3 sec.  Then a...
# 23     NC  UFO seen hovering South East 4 to 6 miles from...
# 24     CA   Orange light travels across sky then disappears.
# 25     NY  I saw a dark silver circle shaped UFO for like...
# 26     IL                            Craft just disappeared.
# 27     SC                 Saucer seen on I-26 and Ladson Rd.
# 28     CO                        White dot over Boulder, CO.
# 29     SC  Multi-colored light seen to the west of Seabro...
# ..    ...                                                ...
# 514    TX  I noticed a couple of lights out in the distan...
# 515    MO  Strange lights hovering near the gateway arch....
# 516    MO  Unusual light over the STL Arch; eyewitness re...
# 517    TX  Witnessed three white lights in triangle forma...
# 518    CA                              2 silver sphere ufos.
# 519    WA                           Bright flash in the sky.
# 520        Myself and my partner where out smoking when w...
# 521    MO  Big bright red-orange object flying horizontal...
# 522    ME  I'm actually not sure of the actually date but...
# 523    VA  Two slow moving strobing lights moving steady ...
# 524    CA    UFOs seen over Chico, CA.  ((anonymous report))
# 525    OH           Hovering disc with two red lights on it.
# 526    ON  LOTS OF ACTIVITY OVER LAKE ERIE DURING FIREWOR...
# 527        Four floating lights, hovered about 500m above...
# 528    OR  We were walking past an athletic field when we...
# 529    WA  I noticed a light way up in the sky, and quick...
# 530    IN  Orange orb gliding above tree line from east t...
# 531    CO       5 colored lights moving in sky east to west.
# 532    NS  Strange balls of light seen in sky over Cape B...
# 533    NE           Black ufo spotted on a late night drive.
# 534    NE  It was late at night the object was a distance...
# 535    ME  Saw a yellowish craft that turned into a disc ...
# 536    FL  Red lights, three, moving from east to west, t...
# 537    FL  Three bright reds lights crossing the sky, and...
# 538    CA                    Two saucers and a lighting bolt
# 539    IA  1000 yards alt, triangular (large) floated ove...
# 540    YT  White triangle with speed of a modern jet. Sky...
# 541        Long, cylindrical plane-like object appeared s...
# 542    CO                                  Sky cracked open.
# 543    AR  It looked like a brown boxcar way up into the ...
#
# [544 rows x 5 columns]

# %%
# SOME MORE EXAMPLES

# %%
# NY TIMES ARTICLES ON HOME PAGE

# %%
response = requests.get("http://www.nytimes.com/")
parser = BeautifulSoup(response.text, "html.parser")
for story in parser.findAll("h2", attrs={'class':'story-heading'}):
    print story.text

# %%
# WIKIPEDIA FEATURED ARTICLE
response = requests.get("https://en.wikipedia.org/wiki/Wikipedia:Today%27s_featured_article")
parser = BeautifulSoup(response.text, "html.parser")

# %%
parser.find('div', attrs={'id':'mw-content-text'}).text
